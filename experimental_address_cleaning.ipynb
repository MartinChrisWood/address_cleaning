# %% [markdown]
# # Clean and Extract Address Components
# With a particular focus on postcodes and countries.  For this project the tools we have are;
# - SpacY (POS tagging)
# - libpostal (which should automatically solve this problem, but has real trouble with miss-ordered addresses, which is why we're doing this)
# - WordNinja (splits strings with no whitespace in to words using a probabilistic tool trained on wikipedia)
# - regex (of course!  In this case an extremely complicated one based off the english ISO standard for postcodes)
# - Any business rules we can dream up
#
# To test how these packages might be used, we've got a dataset of mixed scraped and fake american addresses, embedded in nonsense text, described and available at https://onethinglab.com/2018/03/05/extracting-addresses-from-text/.  This isn't ideal because it's quite dirty - the real problem is explicity entered addresses that people have mucked up entering.
#
# I've also gotten the Companies House free dataset of UK registered company addresses.  These are structured, which means I can creatively "deconstruct" them to create dirty messy human-entered addresses.  A summary of the fields included can be found at http://resources.companieshouse.gov.uk/toolsToHelp/pdf/freeDataProductDataset.pdf.
#
# Finally, a smaller dataset of addresses is available from HM's Land registry, of prices paid for properties (1995 - 2012, no idea why that date window).  It can be gotten from https://data.gov.uk/dataset/314f77b3-e702-4545-8bcb-9ef8262ea0fd/archived-price-paid-information-residential-property-1995-to-2012 and can be abused in the same way as the above CH dataset.  It has the advantage of being small enough to fit in memory so I don't have to sub-sample to get something to experiment with...

# %%
import spacy
import wordninja
import re
import pickle

import numpy as np
import pandas as pd

from random import sample
from random import random
from random import randrange
from random import shuffle
from postal.parser import parse_address  # Python wrapper for libpostal, which is a C library

# %%
# REGEX courtesy commentator "borrible" at stackoverflow thread "https://stackoverflow.com/questions/6409948/php-extract-uk-postal-code-and-validate-it"
postcode_regex = re.compile(r"((GIR 0AA)|((([A-PR-UWYZ][0-9][0-9]?)|(([A-PR-UWYZ][A-HK-Y][0-9][0-9]?)|(([A-PR-UWYZ][0-9][A-HJKSTUW])|([A-PR-UWYZ][A-HK-Y][0-9][ABEHMNPRVWXY])))) ?[0-9][ABD-HJLNP-UW-Z]{2}))")

# %%
#with open("./data/IOB_tagged_addresses.pkl", "rb") as f:
#    data = pickle.load(f)

# %% [markdown]
# ## Fetch Clean Addresses
# From the land registry dataset.  It has all the components, accidental repeats, and valid UK postcodes!  The only thing it lacks is a country, which I will create using a list of example country names/designations added at random (despite the fact they're all uk).  I don't actually know if there's any particular problems with this dataset.

# %%
countries = ['UK', 'U.K', 'U.K', 'CHINA', 'P.R.CHINA', 'TAIWAN CHINA', 'INDIA', 'IRAN']

# %%
lr_dat = pd.read_csv("./data/pp-2012-part1.csv", header=None, nrows=200)

# %%
lr_dat.head()
# Out:
#                                        0       1                 2         3   \
# 0  {BD0D075D-7818-47B3-9657-7651CBD02219}  155000  2012-09-28 00:00  YO24 2XQ
# 1  {0FF70080-C8EA-4DDC-9C19-7651D9B540CC}  264000  2012-07-18 00:00  PO11 9SE
# 2  {80CC2177-EDBE-4ABB-9EAA-7651DAA0E4EE}   20000  2012-04-25 00:00   HU8 8ES
# 3  {076B2969-50D6-4659-8956-7651ECAAB904}   89950  2012-10-25 00:00   S81 0AB
# 4  {9A6B1BBC-3522-4B44-9FD6-765202F73E28}  168000  2012-04-13 00:00   TQ2 7SU
#
#   4  5  6    7    8               9    10              11  \
# 0  S  N  F    9  NaN      IRVINE WAY  NaN            YORK
# 1  D  N  F   16  NaN    TRELOAR ROAD  NaN  HAYLING ISLAND
# 2  T  N  F    8  NaN  LABURNUM GROVE  NaN            HULL
# 3  S  N  F   31  NaN       QUEENSWAY  NaN         WORKSOP
# 4  S  N  F  105  NaN       HERON WAY  NaN         TORQUAY
#
#                            12                          13 14 15
# 0                        YORK                        YORK  A  A
# 1                      HAVANT                   HAMPSHIRE  A  A
# 2  CITY OF KINGSTON UPON HULL  CITY OF KINGSTON UPON HULL  A  A
# 3                   BASSETLAW             NOTTINGHAMSHIRE  A  A
# 4                      TORBAY                      TORBAY  A  A

# %%
clean_addresses = []

# Iterate through addresses, get components
for index, row in lr_dat.iterrows():
    address = {}
    address['postcode'] = str(np.where(str(row[3])=="nan", "", row[3]))
    address['region'] = str(np.where(str(row[13])=="nan", "", row[13]))
    address['street_address'] = " ".join([str(x) for x in row.iloc[7:12] if str(x)!="nan"])
    address['country'] = sample(countries, 1)[0]
    
    clean_addresses.append(address)

# %%
clean_addresses
# Out:
# [{'country': 'UK',
#   'postcode': 'YO24 2XQ',
#   'region': 'YORK',
#   'street_address': '9 IRVINE WAY YORK'},
#  {'country': 'P.R.CHINA',
#   'postcode': 'PO11 9SE',
#   'region': 'HAMPSHIRE',
#   'street_address': '16 TRELOAR ROAD HAYLING ISLAND'},
#  {'country': 'IRAN',
#   'postcode': 'HU8 8ES',
#   'region': 'CITY OF KINGSTON UPON HULL',
#   'street_address': '8 LABURNUM GROVE HULL'},
#  {'country': 'UK',
#   'postcode': 'S81 0AB',
#   'region': 'NOTTINGHAMSHIRE',
#   'street_address': '31 QUEENSWAY WORKSOP'},
#  {'country': 'TAIWAN CHINA',
#   'postcode': 'TQ2 7SU',
#   'region': 'TORBAY',
#   'street_address': '105 HERON WAY TORQUAY'},
#  {'country': 'U.K',
#   'postcode': 'SY13 4AT',
#   'region': 'CHESHIRE EAST',
#   'street_address': 'BURLEYDAM HOUSE WHITCHURCH ROAD BURLEYDAM WHITCHURCH'},
#  {'country': 'IRAN',
#   'postcode': 'ME14 5HW',
#   'region': 'KENT',
#   'street_address': 'PARK HOUSE FLAT 21 PARK AVENUE MAIDSTONE'},
#  {'country': 'U.K',
#   'postcode': 'CH5 4DF',
#   'region': 'FLINTSHIRE',
#   'street_address': '98 HIGH STREET CONNAHS QUAY DEESIDE'},
#  {'country': 'IRAN',
#   'postcode': 'PO9 2RR',
#   'region': 'HAMPSHIRE',
#   'street_address': '1 SOUTHLEIGH ROAD HAVANT'},
#  {'country': 'P.R.CHINA',
#   'postcode': 'BS7 0AZ',
#   'region': 'CITY OF BRISTOL',
#   'street_address': '224 FILTON AVENUE HORFIELD BRISTOL'},
#  {'country': 'UK',
#   'postcode': 'GL2 8JU',
#   'region': 'GLOUCESTERSHIRE',
#   'street_address': 'LEY CROSSING BUNGALOW LEY LANE MINSTERWORTH GLOUCESTER'},
#  {'country': 'CHINA',
#   'postcode': 'BH25 5NQ',
#   'region': 'HAMPSHIRE',
#   'street_address': '222 GORE ROAD NEW MILTON'},
#  {'country': 'UK',
#   'postcode': 'NG4 1JX',
#   'region': 'NOTTINGHAMSHIRE',
#   'street_address': '11A HILLVIEW ROAD CARLTON NOTTINGHAM'},
#  {'country': 'INDIA',
#   'postcode': 'NG17 8PT',
#   'region': 'NOTTINGHAMSHIRE',
#   'street_address': '3 LILAC GROVE KIRKBY IN ASHFIELD NOTTINGHAM'},
#  {'country': 'IRAN',
#   'postcode': 'SN12 6FU',
#   'region': 'WILTSHIRE',
#   'street_address': '20 SAXIFRAGE BANK MELKSHAM'},
#  {'country': 'U.K',
#   'postcode': 'LL18 5WP',
#   'region': 'DENBIGHSHIRE',
#   'street_address': '1 RHODFA FLINT BODELWYDDAN RHYL'},
#  {'country': 'INDIA',
#   'postcode': 'BS16 1FN',
#   'region': 'SOUTH GLOUCESTERSHIRE',
#   'street_address': '5 LITTLE LOCKY CLOSE STOKE GIFFORD BRISTOL'},
#  {'country': 'U.K',
#   'postcode': 'IP13 9BP',
#   'region': 'SUFFOLK',
#   'street_address': '31 CASTLE STREET FRAMLINGHAM WOODBRIDGE'},
#  {'country': 'P.R.CHINA',
#   'postcode': 'IG11 7AL',
#   'region': 'GREATER LONDON',
#   'street_address': '1 ST ANNS BARKING'},
#  {'country': 'INDIA',
#   'postcode': 'MK2 2FB',
#   'region': 'MILTON KEYNES',
#   'street_address': '29 PRINCES WAY BLETCHLEY MILTON KEYNES'},
#  {'country': 'TAIWAN CHINA',
#   'postcode': 'GL50 3LW',
#   'region': 'GLOUCESTERSHIRE',
#   'street_address': '18 CHAPEL STREET CHELTENHAM'},
#  {'country': 'INDIA',
#   'postcode': 'PR9 8RE',
#   'region': 'MERSEYSIDE',
#   'street_address': '20 BAYTREE CLOSE SOUTHPORT'},
#  {'country': 'IRAN',
#   'postcode': 'RG4 7QT',
#   'region': 'READING',
#   'street_address': '280 HEMDEAN ROAD CAVERSHAM READING'},
#  {'country': 'U.K',
#   'postcode': 'DL3 9QD',
#   'region': 'DARLINGTON',
#   'street_address': '11 LAZENBY GROVE DARLINGTON'},
#  {'country': 'U.K',
#   'postcode': 'SE16 7BW',
#   'region': 'GREATER LONDON',
#   'street_address': 'VANCOUVER HOUSE FLAT 107 NEEDLEMAN STREET LONDON'},
#  {'country': 'U.K',
#   'postcode': 'ST1 6AQ',
#   'region': 'STOKE-ON-TRENT',
#   'street_address': 'RIVERSIDE COURT APARTMENT 10 LEEK ROAD STOKE-ON-TRENT'},
#  {'country': 'U.K',
#   'postcode': 'SA7 9PQ',
#   'region': 'SWANSEA',
#   'street_address': '11 LLYS DWRGI BIRCHGROVE SWANSEA'},
#  {'country': 'U.K',
#   'postcode': 'YO24 4DG',
#   'region': 'YORK',
#   'street_address': 'CHANCERY RISE 4 HOLGATE ROAD YORK'},
#  {'country': 'UK',
#   'postcode': 'M30 9JQ',
#   'region': 'GREATER MANCHESTER',
#   'street_address': '13 PARK ROAD ECCLES MANCHESTER'},
#  {'country': 'IRAN',
#   'postcode': 'SW18 3QS',
#   'region': 'GREATER LONDON',
#   'street_address': '42 QUINTON STREET LONDON'},
#  {'country': 'INDIA',
#   'postcode': 'OX13 5BP',
#   'region': 'OXFORDSHIRE',
#   'street_address': '6 STONE HOUSE CLOSE KINGSTON BAGPUIZE ABINGDON'},
#  {'country': 'U.K',
#   'postcode': 'NE22 6JB',
#   'region': 'NORTHUMBERLAND',
#   'street_address': '10 HARTFORD CRESCENT BEDLINGTON'},
#  {'country': 'IRAN',
#   'postcode': 'TS3 9HF',
#   'region': 'MIDDLESBROUGH',
#   'street_address': '74 RAINSFORD CRESCENT MIDDLESBROUGH'},
#  {'country': 'TAIWAN CHINA',
#   'postcode': 'E4 6XS',
#   'region': 'GREATER LONDON',
#   'street_address': '59 STAPLEFORD CLOSE LONDON'},
#  {'country': 'UK',
#   'postcode': 'RH6 9JA',
#   'region': 'SURREY',
#   'street_address': '20 MEADOW WAY HORLEY'},
#  {'country': 'UK',
#   'postcode': 'RH16 1PW',
#   'region': 'WEST SUSSEX',
#   'street_address': '46 PENLAND ROAD HAYWARDS HEATH'},
#  {'country': 'IRAN',
#   'postcode': 'CT6 6EW',
#   'region': 'KENT',
#   'street_address': '62 HERNE AVENUE HERNE BAY'},
#  {'country': 'CHINA',
#   'postcode': 'DE4 5EZ',
#   'region': 'DERBYSHIRE',
#   'street_address': 'BARLEY COTTAGES 2 THE CLIFF MATLOCK'},
#  {'country': 'UK',
#   'postcode': 'B73 5QE',
#   'region': 'WEST MIDLANDS',
#   'street_address': '50 HIGHBRIDGE ROAD SUTTON COLDFIELD'},
#  {'country': 'IRAN',
#   'postcode': 'PE36 5PD',
#   'region': 'NORFOLK',
#   'street_address': '15 ANDREWS PLACE HUNSTANTON'},
#  {'country': 'TAIWAN CHINA',
#   'postcode': 'CV7 9PW',
#   'region': 'WARWICKSHIRE',
#   'street_address': '96 TRESILLIAN ROAD EXHALL COVENTRY'},
#  {'country': 'IRAN',
#   'postcode': 'RG2 7HA',
#   'region': 'READING',
#   'street_address': '28A NORTHCOURT AVENUE READING'},
#  {'country': 'UK',
#   'postcode': 'PE13 5HA',
#   'region': 'CAMBRIDGESHIRE',
#   'street_address': 'ARIES FERRY LANE NEWTON WISBECH'},
#  {'country': 'U.K',
#   'postcode': 'WR15 8LB',
#   'region': 'SHROPSHIRE',
#   'street_address': 'WOODLANDS ARCHERS WAY BURFORD TENBURY WELLS'},
#  {'country': 'UK',
#   'postcode': 'BN6 9JR',
#   'region': 'WEST SUSSEX',
#   'street_address': '6 OSBORN CLOSE SAYERS COMMON HASSOCKS'},
#  {'country': 'TAIWAN CHINA',
#   'postcode': 'SW19 1SS',
#   'region': 'GREATER LONDON',
#   'street_address': 'CLOISTERS HOUSE, 53 FLAT 20 GRIFFITHS ROAD LONDON'},
#  {'country': 'U.K',
#   'postcode': 'BS35 2DY',
#   'region': 'SOUTH GLOUCESTERSHIRE',
#   'street_address': '34 DOVEDALE THORNBURY BRISTOL'},
#  {'country': 'UK',
#   'postcode': 'S9 3DJ',
#   'region': 'SOUTH YORKSHIRE',
#   'street_address': '18 FAY CRESCENT SHEFFIELD'},
#  {'country': 'INDIA',
#   'postcode': 'DA3 7HJ',
#   'region': 'KENT',
#   'street_address': '16 FERNDENE LONGFIELD'},
#  {'country': 'U.K',
#   'postcode': 'SE18 6FE',
#   'region': 'GREATER LONDON',
#   'street_address': 'WAREHOUSE COURT FLAT 176 MAJOR DRAPER STREET LONDON'},
#  {'country': 'UK',
#   'postcode': 'BN22 8XJ',
#   'region': 'EAST SUSSEX',
#   'street_address': '25 MAYFIELD PLACE EASTBOURNE'},
#  {'country': 'U.K',
#   'postcode': 'LS6 4SE',
#   'region': 'WEST YORKSHIRE',
#   'street_address': '34 WOODLEA GARDENS MEANWOOD LEEDS'},
#  {'country': 'U.K',
#   'postcode': 'RG30 2HT',
#   'region': 'READING',
#   'street_address': '49 ELM PARK READING'},
#  {'country': 'CHINA',
#   'postcode': 'KT6 4AW',
#   'region': 'GREATER LONDON',
#   'street_address': '99 FLAT 2 MAPLE ROAD SURBITON'},
#  {'country': 'UK',
#   'postcode': 'RH16 4ER',
#   'region': 'WEST SUSSEX',
#   'street_address': '8 REDWOOD DRIVE HAYWARDS HEATH'},
#  {'country': 'CHINA',
#   'postcode': 'CO4 9GD',
#   'region': 'ESSEX',
#   'street_address': '5 ALVERTON WAY HIGHWOODS COLCHESTER'},
#  {'country': 'P.R.CHINA',
#   'postcode': 'LS16 7RJ',
#   'region': 'WEST YORKSHIRE',
#   'street_address': '20 HOLTDALE PLACE LEEDS'},
#  {'country': 'UK',
#   'postcode': 'YO15 3HS',
#   'region': 'EAST RIDING OF YORKSHIRE',
#   'street_address': '46 NEW BURLINGTON ROAD BRIDLINGTON'},
#  {'country': 'TAIWAN CHINA',
#   'postcode': 'RH5 4SG',
#   'region': 'SURREY',
#   'street_address': '40 OAK CORNER BEARE GREEN DORKING'},
#  {'country': 'TAIWAN CHINA',
#   'postcode': 'ST4 8FJ',
#   'region': 'STOKE-ON-TRENT',
#   'street_address': '87 EDGBASTON DRIVE STOKE-ON-TRENT'},
#  {'country': 'U.K',
#   'postcode': 'CH48 3HR',
#   'region': 'MERSEYSIDE',
#   'street_address': '12 HYDRO AVENUE WIRRAL'},
#  {'country': 'INDIA',
#   'postcode': 'CF14 2TJ',
#   'region': 'CARDIFF',
#   'street_address': 'GLENDOWER COURT FLAT 4 VELINDRE ROAD CARDIFF'},
#  {'country': 'INDIA',
#   'postcode': 'NG5 7EZ',
#   'region': 'NOTTINGHAMSHIRE',
#   'street_address': '34 BENTWELL AVENUE ARNOLD NOTTINGHAM'},
#  {'country': 'CHINA',
#   'postcode': 'BH3 7JZ',
#   'region': 'BOURNEMOUTH',
#   'street_address': '20 FLAT 2 GERALD ROAD BOURNEMOUTH'},
#  {'country': 'U.K',
#   'postcode': 'DA15 9HA',
#   'region': 'GREATER LONDON',
#   'street_address': '42 PORTLAND AVENUE SIDCUP'},
#  {'country': 'U.K',
#   'postcode': 'DE22 4DH',
#   'region': 'CITY OF DERBY',
#   'street_address': '53 ENFIELD ROAD DERBY'},
#  {'country': 'U.K',
#   'postcode': 'MK18 1DW',
#   'region': 'BUCKINGHAMSHIRE',
#   'street_address': '7 MITRE STREET BUCKINGHAM'},
#  {'country': 'INDIA',
#   'postcode': 'W1W 6DP',
#   'region': 'GREATER LONDON',
#   'street_address': 'QUANTOCK HOUSE, 20 FLAT 4 FOLEY STREET LONDON'},
#  {'country': 'TAIWAN CHINA',
#   'postcode': 'CA2 6LF',
#   'region': 'CUMBRIA',
#   'street_address': '56 WESTRIGG ROAD CARLISLE'},
#  {'country': 'IRAN',
#   'postcode': 'CO16 9PZ',
#   'region': 'ESSEX',
#   'street_address': '283 HARWICH ROAD LITTLE CLACTON CLACTON-ON-SEA'},
#  {'country': 'CHINA',
#   'postcode': 'PO13 9SE',
#   'region': 'HAMPSHIRE',
#   'street_address': '27 HENVILLE CLOSE ROWNER GOSPORT'},
#  {'country': 'U.K',
#   'postcode': 'TN13 1JE',
#   'region': 'KENT',
#   'street_address': '4 SIX BELLS LANE SEVENOAKS'},
#  {'country': 'IRAN',
#   'postcode': 'B30 2JA',
#   'region': 'WEST MIDLANDS',
#   'street_address': '2 SHIRLEY ROAD KINGS NORTON BIRMINGHAM'},
#  {'country': 'TAIWAN CHINA',
#   'postcode': 'SA6 7EG',
#   'region': 'SWANSEA',
#   'street_address': '26 LON CAMLAD MORRISTON SWANSEA'},
#  {'country': 'CHINA',
#   'postcode': 'TS25 5BJ',
#   'region': 'HARTLEPOOL',
#   'street_address': '60 HASWELL AVENUE HARTLEPOOL'},
#  {'country': 'INDIA',
#   'postcode': 'WA5 1EZ',
#   'region': 'WARRINGTON',
#   'street_address': '7 THURSTON CLOSE GREAT SANKEY WARRINGTON'},
#  {'country': 'CHINA',
#   'postcode': 'LE17 6LR',
#   'region': 'LEICESTERSHIRE',
#   'street_address': '16 MOWSLEY ROAD HUSBANDS BOSWORTH LUTTERWORTH'},
#  {'country': 'U.K',
#   'postcode': 'LL36 9DY',
#   'region': 'GWYNEDD',
#   'street_address': '14 BRYN HEULOG TYWYN'},
#  {'country': 'CHINA',
#   'postcode': 'CF39 9LF',
#   'region': 'RHONDDA CYNON TAFF',
#   'street_address': '45 GLYNFACH ROAD PORTH'},
#  {'country': 'U.K',
#   'postcode': 'SW18 4QL',
#   'region': 'GREATER LONDON',
#   'street_address': '30 DUNTSHILL ROAD LONDON'},
#  {'country': 'U.K',
#   'postcode': 'SN3 1JZ',
#   'region': 'SWINDON',
#   'street_address': '10 WARDOUR CLOSE SWINDON'},
#  {'country': 'UK',
#   'postcode': 'E3 3GU',
#   'region': 'GREATER LONDON',
#   'street_address': 'ALBORAN APARTMENTS, 1 FLAT 302 SEVEN SEA GARDENS LONDON'},
#  {'country': 'TAIWAN CHINA',
#   'postcode': 'CB6 1DE',
#   'region': 'CAMBRIDGESHIRE',
#   'street_address': '56 LYNN ROAD ELY'},
#  {'country': 'U.K',
#   'postcode': 'IP31 3PJ',
#   'region': 'SUFFOLK',
#   'street_address': 'WESTCOMBE HEATH ROAD THURSTON BURY ST EDMUNDS'},
#  {'country': 'UK',
#   'postcode': 'WR11 8TH',
#   'region': 'WORCESTERSHIRE',
#   'street_address': 'OBEM LONG HYDE ROAD SOUTH LITTLETON EVESHAM'},
#  {'country': 'CHINA',
#   'postcode': 'CH43 7QE',
#   'region': 'MERSEYSIDE',
#   'street_address': '143 UPTON ROAD PRENTON'},
#  {'country': 'TAIWAN CHINA',
#   'postcode': 'TN4 9SB',
#   'region': 'KENT',
#   'street_address': '13 CULVERDEN DOWN TUNBRIDGE WELLS'},
#  {'country': 'P.R.CHINA',
#   'postcode': 'TW17 0EX',
#   'region': 'SURREY',
#   'street_address': '54 WATERSPLASH ROAD SHEPPERTON'},
#  {'country': 'INDIA',
#   'postcode': 'WF7 7BB',
#   'region': 'WEST YORKSHIRE',
#   'street_address': '13 GARDEN STREET ACKWORTH PONTEFRACT'},
#  {'country': 'INDIA',
#   'postcode': 'SM6 7LJ',
#   'region': 'GREATER LONDON',
#   'street_address': '10 BERKELEY COURT WALLINGTON'},
#  {'country': 'UK',
#   'postcode': 'RH20 1DZ',
#   'region': 'WEST SUSSEX',
#   'street_address': '17 MASONS WAY CODMORE HILL PULBOROUGH'},
#  {'country': 'U.K',
#   'postcode': 'LE16 9DA',
#   'region': 'LEICESTERSHIRE',
#   'street_address': '130 COVENTRY ROAD MARKET HARBOROUGH'},
#  {'country': 'U.K',
#   'postcode': 'HP18 0FG',
#   'region': 'BUCKINGHAMSHIRE',
#   'street_address': '6 JOHN FITZJOHN AVENUE AYLESBURY'},
#  {'country': 'U.K',
#   'postcode': 'NN12 6UQ',
#   'region': 'NORTHAMPTONSHIRE',
#   'street_address': '83 HAZEL CRESCENT TOWCESTER'},
#  {'country': 'UK',
#   'postcode': 'NP7 6HN',
#   'region': 'MONMOUTHSHIRE',
#   'street_address': '74 ST ANDREWS CRESCENT ABERGAVENNY'},
#  {'country': 'P.R.CHINA',
#   'postcode': 'WR4 0QW',
#   'region': 'WORCESTERSHIRE',
#   'street_address': '6 HUNT AVENUE WORCESTER'},
#  {'country': 'CHINA',
#   'postcode': 'GU9 0NW',
#   'region': 'SURREY',
#   'street_address': 'TANGLEWOOD OAST HOUSE LANE FARNHAM'},
#  {'country': 'P.R.CHINA',
#   'postcode': 'SN3 4GL',
#   'region': 'SWINDON',
#   'street_address': '4 STATION HALT SWINDON'},
#  {'country': 'IRAN',
#   'postcode': 'NG9 7DZ',
#   'region': 'NOTTINGHAMSHIRE',
#   'street_address': '1 TUDOR COURT STAPLEFORD NOTTINGHAM'},
#  {'country': 'UK',
#   'postcode': 'RG30 4PB',
#   'region': 'READING',
#   'street_address': '312 THE MEADWAY TILEHURST READING'},
#  {'country': 'UK',
#   'postcode': 'SW4 0PE',
#   'region': 'GREATER LONDON',
#   'street_address': '119 VICTORIA RISE LONDON'},
#  {'country': 'UK',
#   'postcode': 'S71 4FN',
#   'region': 'SOUTH YORKSHIRE',
#   'street_address': '16 MELTON WAY ROYSTON BARNSLEY'},
#  {'country': 'TAIWAN CHINA',
#   'postcode': 'DE65 5NL',
#   'region': 'DERBYSHIRE',
#   'street_address': '49 EDEN CLOSE HILTON DERBY'},
#  {'country': 'P.R.CHINA',
#   'postcode': 'CF15 9TA',
#   'region': 'CARDIFF',
#   'street_address': '39 BRON HAUL PENTYRCH CARDIFF'},
#  {'country': 'TAIWAN CHINA',
#   'postcode': 'IG9 5FE',
#   'region': 'ESSEX',
#   'street_address': '100 BROOK ROAD BUCKHURST HILL'},
#  {'country': 'U.K',
#   'postcode': 'PO16 9DQ',
#   'region': 'HAMPSHIRE',
#   'street_address': '6 BRENCHLEY CLOSE FAREHAM'},
#  {'country': 'UK',
#   'postcode': 'RM15 4AD',
#   'region': 'THURROCK',
#   'street_address': '20 HIGH STREET AVELEY SOUTH OCKENDON'},
#  {'country': 'CHINA',
#   'postcode': 'ME17 4DG',
#   'region': 'KENT',
#   'street_address': '14 WESTERHILL ROAD COXHEATH MAIDSTONE'},
#  {'country': 'TAIWAN CHINA',
#   'postcode': 'NN29 7JS',
#   'region': 'NORTHAMPTONSHIRE',
#   'street_address': '16 BOSGATE CLOSE BOZEAT WELLINGBOROUGH'},
#  {'country': 'CHINA',
#   'postcode': 'N10 1QG',
#   'region': 'GREATER LONDON',
#   'street_address': 'BARRINGTON COURT FLAT 7 COLNEY HATCH LANE LONDON'},
#  {'country': 'UK',
#   'postcode': 'CB8 0AY',
#   'region': 'SUFFOLK',
#   'street_address': '193 EXNING ROAD NEWMARKET'},
#  {'country': 'P.R.CHINA',
#   'postcode': 'LN6 0NT',
#   'region': 'LINCOLNSHIRE',
#   'street_address': '5 LECONFIELD ROAD LINCOLN'},
#  {'country': 'CHINA',
#   'postcode': 'KT8 9DE',
#   'region': 'SURREY',
#   'street_address': 'ANN BOLEYN HOUSE FLAT 23 QUEENS REACH EAST MOLESEY'},
#  {'country': 'U.K',
#   'postcode': 'N6 5UG',
#   'region': 'GREATER LONDON',
#   'street_address': '14C MUSWELL HILL ROAD LONDON'},
#  {'country': 'CHINA',
#   'postcode': 'SW8 3JG',
#   'region': 'GREATER LONDON',
#   'street_address': '771 WANDSWORTH ROAD LONDON'},
#  {'country': 'U.K',
#   'postcode': 'HD8 0TX',
#   'region': 'WEST YORKSHIRE',
#   'street_address': 'LINFIT MILL, 16 FLAT 5 LINFIT LANE KIRKBURTON HUDDERSFIELD'},
#  {'country': 'U.K',
#   'postcode': 'WV6 8AF',
#   'region': 'WEST MIDLANDS',
#   'street_address': '71 BRIDGNORTH ROAD WOLVERHAMPTON'},
#  {'country': 'IRAN',
#   'postcode': 'KT16 9GU',
#   'region': 'SURREY',
#   'street_address': 'LIBERTY HOUSE FLAT 6 GUILDFORD STREET CHERTSEY'},
#  {'country': 'TAIWAN CHINA',
#   'postcode': 'BL6 7BY',
#   'region': 'GREATER MANCHESTER',
#   'street_address': '2 LEE LANE HORWICH BOLTON'},
#  {'country': 'UK',
#   'postcode': 'B26 3AR',
#   'region': 'WEST MIDLANDS',
#   'street_address': '57 BEECHMORE ROAD BIRMINGHAM'},
#  {'country': 'TAIWAN CHINA',
#   'postcode': 'OX7 5DN',
#   'region': 'OXFORDSHIRE',
#   'street_address': '3 WALTERBUSH ROAD CHIPPING NORTON'},
#  {'country': 'TAIWAN CHINA',
#   'postcode': 'E9 5FA',
#   'region': 'GREATER LONDON',
#   'street_address': 'SKY APARTMENTS FLAT 42 HOMERTON ROAD LONDON'},
#  {'country': 'IRAN',
#   'postcode': 'PL26 8UP',
#   'region': 'CORNWALL',
#   'street_address': '4 PENHALE ROAD PENWITHICK ST AUSTELL'},
#  {'country': 'U.K',
#   'postcode': 'BS37 7YJ',
#   'region': 'SOUTH GLOUCESTERSHIRE',
#   'street_address': '20 HAY LEAZE YATE BRISTOL'},
#  {'country': 'IRAN',
#   'postcode': 'SG19 3RL',
#   'region': 'CAMBRIDGESHIRE',
#   'street_address': '23 AUDLEY CLOSE GREAT GRANSDEN SANDY'},
#  {'country': 'UK',
#   'postcode': 'NG4 3PU',
#   'region': 'NOTTINGHAMSHIRE',
#   'street_address': '8 MARWOOD ROAD CARLTON NOTTINGHAM'},
#  {'country': 'INDIA',
#   'postcode': 'LL46 2SL',
#   'region': 'GWYNEDD',
#   'street_address': '2 PENYBRYN ESTATE HARLECH'},
#  {'country': 'P.R.CHINA',
#   'postcode': 'SE18 6FB',
#   'region': 'GREATER LONDON',
#   'street_address': 'WAREHOUSE COURT FLAT 11 NO 1 STREET LONDON'},
#  {'country': 'CHINA',
#   'postcode': 'SA73 3JU',
#   'region': 'PEMBROKESHIRE',
#   'street_address': 'THE VICARAGE SANDHURST ROAD MILFORD HAVEN'},
#  {'country': 'INDIA',
#   'postcode': 'N17 6UJ',
#   'region': 'GREATER LONDON',
#   'street_address': '103 SPERLING ROAD LONDON'},
#  {'country': 'TAIWAN CHINA',
#   'postcode': 'OX27 9BJ',
#   'region': 'OXFORDSHIRE',
#   'street_address': 'MANOR COTTAGE MILL ROAD STRATTON AUDLEY BICESTER'},
#  {'country': 'P.R.CHINA',
#   'postcode': 'NN14 1BY',
#   'region': 'NORTHAMPTONSHIRE',
#   'street_address': '21 CARDIGAN ROAD STANION KETTERING'},
#  {'country': 'U.K',
#   'postcode': 'PO38 1XT',
#   'region': 'ISLE OF WIGHT',
#   'street_address': 'MADEIRA HUNTS ROAD ST LAWRENCE VENTNOR'},
#  {'country': 'P.R.CHINA',
#   'postcode': 'PR7 4RL',
#   'region': 'LANCASHIRE',
#   'street_address': '28 CARRINGTON ROAD ADLINGTON CHORLEY'},
#  {'country': 'CHINA',
#   'postcode': 'S63 0AU',
#   'region': 'SOUTH YORKSHIRE',
#   'street_address': '21 ACORN AVENUE THURNSCOE ROTHERHAM'},
#  {'country': 'IRAN',
#   'postcode': 'E18 2QA',
#   'region': 'GREATER LONDON',
#   'street_address': '68 FULLERS ROAD LONDON'},
#  {'country': 'INDIA',
#   'postcode': 'PE9 1BS',
#   'region': 'LINCOLNSHIRE',
#   'street_address': '14 PEMBROKE ROAD STAMFORD'},
#  {'country': 'UK',
#   'postcode': 'BS24 9NQ',
#   'region': 'NORTH SOMERSET',
#   'street_address': '4 MAIDSTONE GROVE WESTON-SUPER-MARE'},
#  {'country': 'U.K',
#   'postcode': 'MK43 7BP',
#   'region': 'BEDFORD',
#   'street_address': '49 ORCHARD LANE HARROLD BEDFORD'},
#  {'country': 'TAIWAN CHINA',
#   'postcode': 'EX32 9LW',
#   'region': 'DEVON',
#   'street_address': '77 HUGHES AVENUE BARNSTAPLE'},
#  {'country': 'CHINA',
#   'postcode': 'PE15 0ST',
#   'region': 'CAMBRIDGESHIRE',
#   'street_address': 'BYWAYS PRIMROSE HILL DODDINGTON MARCH'},
#  {'country': 'TAIWAN CHINA',
#   'postcode': 'CB6 1AY',
#   'region': 'CAMBRIDGESHIRE',
#   'street_address': '2 HILLS LANE ELY'},
#  {'country': 'U.K',
#   'postcode': 'N22 7UY',
#   'region': 'GREATER LONDON',
#   'street_address': '2 YEWTREE CLOSE LONDON'},
#  {'country': 'P.R.CHINA',
#   'postcode': 'SO30 2RL',
#   'region': 'HAMPSHIRE',
#   'street_address': '6 WALKER GARDENS HEDGE END SOUTHAMPTON'},
#  {'country': 'IRAN',
#   'postcode': 'BR1 3LX',
#   'region': 'GREATER LONDON',
#   'street_address': '20 FLAT 1 GARDEN ROAD BROMLEY'},
#  {'country': 'UK',
#   'postcode': 'E8 4NR',
#   'region': 'GREATER LONDON',
#   'street_address': '52 BROWNLOW ROAD LONDON'},
#  {'country': 'UK',
#   'postcode': 'CB7 4UN',
#   'region': 'CAMBRIDGESHIRE',
#   'street_address': 'SALIX MAIN STREET PRICKWILLOW ELY'},
#  {'country': 'U.K',
#   'postcode': 'SK8 2LQ',
#   'region': 'GREATER MANCHESTER',
#   'street_address': '22 ARGYLL ROAD CHEADLE'},
#  {'country': 'INDIA',
#   'postcode': 'BA14 7TG',
#   'region': 'WILTSHIRE',
#   'street_address': '76 LACOCK GARDENS HILPERTON TROWBRIDGE'},
#  {'country': 'INDIA',
#   'postcode': 'TW9 2HN',
#   'region': 'GREATER LONDON',
#   'street_address': '4 STANMORE GARDENS RICHMOND'},
#  {'country': 'CHINA',
#   'postcode': 'SO31 5AG',
#   'region': 'HAMPSHIRE',
#   'street_address': '3 LATELIE CLOSE NETLEY ABBEY SOUTHAMPTON'},
#  {'country': 'TAIWAN CHINA',
#   'postcode': 'SL5 9DJ',
#   'region': 'WINDSOR AND MAIDENHEAD',
#   'street_address': '7 BROCKENHURST ROAD ASCOT'},
#  {'country': 'U.K',
#   'postcode': 'CF62 8AZ',
#   'region': 'THE VALE OF GLAMORGAN',
#   'street_address': '43 TYNEWYDD ROAD BARRY'},
#  {'country': 'U.K',
#   'postcode': 'B92 0BB',
#   'region': 'WEST MIDLANDS',
#   'street_address': '30 FENTHAM ROAD HAMPTON IN ARDEN SOLIHULL'},
#  {'country': 'CHINA',
#   'postcode': 'NN14 1AY',
#   'region': 'NORTHAMPTONSHIRE',
#   'street_address': '25 QUEEN ELEANOR ROAD GEDDINGTON KETTERING'},
#  {'country': 'UK',
#   'postcode': 'S75 2QU',
#   'region': 'SOUTH YORKSHIRE',
#   'street_address': '7 WILSDEN GROVE BARNSLEY'},
#  {'country': 'P.R.CHINA',
#   'postcode': 'DN20 8BX',
#   'region': 'NORTH LINCOLNSHIRE',
#   'street_address': '2 ST HELENS ROAD BRIGG'},
#  {'country': 'UK',
#   'postcode': 'CT9 3TJ',
#   'region': 'KENT',
#   'street_address': '173 MILLMEAD ROAD MARGATE'},
#  {'country': 'U.K',
#   'postcode': 'GL20 6FL',
#   'region': 'GLOUCESTERSHIRE',
#   'street_address': 'AVON COTTAGE FLEET LANE TWYNING TEWKESBURY'},
#  {'country': 'IRAN',
#   'postcode': 'HD3 3LD',
#   'region': 'WEST YORKSHIRE',
#   'street_address': '23 WEATHERHILL ROAD HUDDERSFIELD'},
#  {'country': 'TAIWAN CHINA',
#   'postcode': 'DE14 2QJ',
#   'region': 'STAFFORDSHIRE',
#   'street_address': '5 BLAKEHOLME COURT BURTON-ON-TRENT'},
#  {'country': 'INDIA',
#   'postcode': 'SW12 9LQ',
#   'region': 'GREATER LONDON',
#   'street_address': '84 DAGNAN ROAD LONDON'},
#  {'country': 'TAIWAN CHINA',
#   'postcode': 'ME16 0BA',
#   'region': 'KENT',
#   'street_address': '10 HAZEL AVENUE MAIDSTONE'},
#  {'country': 'INDIA',
#   'postcode': 'SS17 9HT',
#   'region': 'THURROCK',
#   'street_address': 'CHY-AN-DOUR HIGH ROAD FOBBING STANFORD-LE-HOPE'},
#  {'country': 'U.K',
#   'postcode': 'S70 6HP',
#   'region': 'SOUTH YORKSHIRE',
#   'street_address': '24 WESTBOURNE TERRACE BARNSLEY'},
#  {'country': 'TAIWAN CHINA',
#   'postcode': 'LE16 7JR',
#   'region': 'LEICESTERSHIRE',
#   'street_address': '19 HEYGATE STREET MARKET HARBOROUGH'},
#  {'country': 'TAIWAN CHINA',
#   'postcode': 'CM3 5YQ',
#   'region': 'ESSEX',
#   'street_address': '10 BEATTY RISE SOUTH WOODHAM FERRERS CHELMSFORD'},
#  {'country': 'U.K',
#   'postcode': 'HU3 3AR',
#   'region': 'CITY OF KINGSTON UPON HULL',
#   'street_address': '16 VICTORIA AVENUE HULL'},
#  {'country': 'INDIA',
#   'postcode': 'CA1 1LJ',
#   'region': 'CUMBRIA',
#   'street_address': '223 WARWICK ROAD CARLISLE'},
#  {'country': 'CHINA',
#   'postcode': 'PE31 7HZ',
#   'region': 'NORFOLK',
#   'street_address': "KELMSCOT, 11 RINGSTEAD ROAD HEACHAM KING'S LYNN"},
#  {'country': 'U.K',
#   'postcode': 'BB10 3JW',
#   'region': 'LANCASHIRE',
#   'street_address': '161 BROWNSIDE ROAD BURNLEY'},
#  {'country': 'P.R.CHINA',
#   'postcode': 'LD3 7FE',
#   'region': 'POWYS',
#   'street_address': 'THE BARN 2 CROSS YARD BRECON'},
#  {'country': 'U.K',
#   'postcode': 'SA6 6AX',
#   'region': 'SWANSEA',
#   'street_address': '2 TELYN AUR MORRISTON SWANSEA'},
#  {'country': 'U.K',
#   'postcode': 'SG18 9BU',
#   'region': 'CENTRAL BEDFORDSHIRE',
#   'street_address': '116 HITCHIN ROAD UPPER CALDECOTE BIGGLESWADE'},
#  {'country': 'IRAN',
#   'postcode': 'NP13 3BX',
#   'region': 'BLAENAU GWENT',
#   'street_address': '1 CHAPEL ROAD BLAINA ABERTILLERY'},
#  {'country': 'UK',
#   'postcode': 'SS14 3JG',
#   'region': 'ESSEX',
#   'street_address': '42 MONTAGUE STREET BASILDON'},
#  {'country': 'IRAN',
#   'postcode': 'RH14 9SF',
#   'region': 'WEST SUSSEX',
#   'street_address': '38 MORRIS DRIVE BILLINGSHURST'},
#  {'country': 'INDIA',
#   'postcode': 'TQ12 1QZ',
#   'region': 'DEVON',
#   'street_address': '4 STONELEIGH CLOSE NEWTON ABBOT'},
#  {'country': 'U.K',
#   'postcode': 'EN6 1DG',
#   'region': 'HERTFORDSHIRE',
#   'street_address': '18 MANOR ROAD POTTERS BAR'},
#  {'country': 'INDIA',
#   'postcode': 'SO51 7NG',
#   'region': 'HAMPSHIRE',
#   'street_address': 'HILL HOUSE THE CRESCENT ROMSEY'},
#  {'country': 'INDIA',
#   'postcode': 'SN25 4AB',
#   'region': 'SWINDON',
#   'street_address': '40 HAYWAIN CLOSE SWINDON'},
#  {'country': 'CHINA',
#   'postcode': 'GU11 3EU',
#   'region': 'HAMPSHIRE',
#   'street_address': '16 VINE STREET ALDERSHOT'},
#  {'country': 'TAIWAN CHINA',
#   'postcode': 'CF81 8NL',
#   'region': 'CAERPHILLY',
#   'street_address': '38 HILLSIDE PARK BARGOED'},
#  {'country': 'P.R.CHINA',
#   'postcode': 'TS1 4ET',
#   'region': 'MIDDLESBROUGH',
#   'street_address': '2 WENTWORTH STREET MIDDLESBROUGH'},
#  {'country': 'INDIA',
#   'postcode': 'NN16 8UH',
#   'region': 'NORTHAMPTONSHIRE',
#   'street_address': '79 DERWENT CRESCENT KETTERING'},
#  {'country': 'UK',
#   'postcode': 'IP28 6DN',
#   'region': 'SUFFOLK',
#   'street_address': 'THE LONE PINE THE STREET CULFORD BURY ST EDMUNDS'},
#  {'country': 'U.K',
#   'postcode': 'LS28 5FF',
#   'region': 'WEST YORKSHIRE',
#   'street_address': '12 POPLAR FARM LANE FARSLEY PUDSEY'},
#  {'country': 'CHINA',
#   'postcode': 'TW19 7HY',
#   'region': 'SURREY',
#   'street_address': '35 ST MARYS CRESCENT STANWELL STAINES'},
#  {'country': 'TAIWAN CHINA',
#   'postcode': 'LA9 6HA',
#   'region': 'CUMBRIA',
#   'street_address': '19 BROAD ING CRESCENT KENDAL'},
#  {'country': 'P.R.CHINA',
#   'postcode': 'DA3 8QW',
#   'region': 'KENT',
#   'street_address': '36 WESTFIELD NEW ASH GREEN LONGFIELD'},
#  {'country': 'U.K',
#   'postcode': 'B26 3SL',
#   'region': 'WEST MIDLANDS',
#   'street_address': '28 IVYDALE AVENUE SHELDON BIRMINGHAM'},
#  {'country': 'U.K',
#   'postcode': 'WN1 3PZ',
#   'region': 'GREATER MANCHESTER',
#   'street_address': '26 NORTHUMBERLAND STREET WIGAN'},
#  {'country': 'IRAN',
#   'postcode': 'DL6 1AR',
#   'region': 'NORTH YORKSHIRE',
#   'street_address': '31 CROSBY GARDENS NORTHALLERTON'},
#  {'country': 'INDIA',
#   'postcode': 'ST4 8RT',
#   'region': 'STOKE-ON-TRENT',
#   'street_address': '46 JAVA CRESCENT STOKE-ON-TRENT'},
#  {'country': 'TAIWAN CHINA',
#   'postcode': 'CF44 6RR',
#   'region': 'RHONDDA CYNON TAFF',
#   'street_address': '22 WYNDHAM CRESCENT ABERDARE'},
#  {'country': 'P.R.CHINA',
#   'postcode': 'WF2 0BH',
#   'region': 'WEST YORKSHIRE',
#   'street_address': '20 LINDALE MOUNT WAKEFIELD'},
#  {'country': 'U.K',
#   'postcode': 'PO20 0BS',
#   'region': 'WEST SUSSEX',
#   'street_address': '70 EAST STREET SELSEY CHICHESTER'},
#  {'country': 'INDIA',
#   'postcode': 'B24 9AP',
#   'region': 'WEST MIDLANDS',
#   'street_address': '65 TRAFALGAR ROAD ERDINGTON BIRMINGHAM'},
#  {'country': 'IRAN',
#   'postcode': 'SL9 8FG',
#   'region': 'BUCKINGHAMSHIRE',
#   'street_address': '15 THE PARK GERRARDS CROSS'},
#  {'country': 'IRAN',
#   'postcode': 'LL30 2DL',
#   'region': 'CONWY',
#   'street_address': '5 SALISBURY COURT LLANDUDNO'}]

# %% [markdown]
# ## Build a Method to turn them in to Dirty Addresses
#
# Mistakes to generate;
# - randomly missed whitespaces
# - randomly inserted whitespaces (esp. in postcode)
# - postcodes moved within address
# - country moved within address
# - postcode or country with parentheses around them (and often in the wrong place!)
# - postcode or country with quotation marks around them
# - all whitespace missing (special for post code extraction)
# - "TEL=XXX..." or "FAX=XXX" with or without equals sign (might be space)

# %%
def fubar_address(address, chance=0.1, deletions=False, delete_chance=0.1):
    dirty = address.copy()
    
    # Step 1 - add parentheses or quotation marks (country, or postcode)
    if random() <= chance:
        if random() < 0.5:
            dirty['postcode'] = "(" + dirty['postcode'] + ")"
        else:
            dirty['postcode'] = "'" + dirty['postcode'] + "'"
    
    if random() <= chance:
        if random() < 0.5:
            dirty['country'] = "(" + dirty['country'] + ")"
        else:
            dirty['country'] = "'" + dirty['country'] + "'"
    
    # Step 2 - shuffle components (country or postcode)
    postcode_shift=0
    country_shift=0
    if random() <= chance:
        postcode_shift = randrange(-2, 1)
    if random() <= chance:
        country_shift = randrange(-3, 0)

    # Step 3 - shuffle street address tokens (with much smaller random chance)
    if random() <= chance:
        street_address = dirty['street_address'].split(" ")
        shuffle(street_address)
        dirty['street_address'] = " ".join(street_address)
    
    # Rebuild the address
    dirty_list = [dirty['street_address'], dirty['region'], "", ""]
    dirty_list.insert(2+postcode_shift, dirty['postcode'])
    dirty_list.insert(3+country_shift, dirty['country'])
    dirty_list = [x for x in dirty_list if x!=""]

    # Step 4 - Append 'TEL=987987 001203'
    if random() <= chance:
        dirty_list.append("TEL=987987 001203")
        
    if random() <= chance:
        dirty_list.append("FAX=65465412")
        
    # Step 5 - drop entire words at random, convert to string
    if deletions == True:
        dirty_string = " ".join([x for x in " ".join(dirty_list).split() if random() >= delete_chance])
        
        # Step 6 - randomly delete characters
        dirty_string = "".join([x for x in dirty_string if random() >= (delete_chance)])
        
        # Step 7 - randomly delete whitespace (with greater probability)
        dirty_string = "".join([x for x in dirty_string if (x != " ") or (random() >= (delete_chance))])
        
    else:
        dirty_string = " ".join(dirty_list)
    
    return dirty_string

# %%
fubar_address(clean_addresses[3], chance=0.2, deletions=True, delete_chance=0)
# Out:
# "31 QUEENSWAY WORKSOP NOTTINGHAMSHIRE 'S81 0AB' UK"

# %% [markdown]
# ## Try running addresses through libpostal
# And record whether or not the postcode and country are successfully retrieved!

# %%
for address in clean_addresses:
    print(address)
    
    # Mess up the address (right now set to "no interference")
    address['dirty'] = fubar_address(address, chance=0)
    
    # Try to parse the address
    address['parsed'] = {y:x for x, y in parse_address(address['dirty'])}
    
    # Detect if postcode retrieval worked
    try:
        address['postcode_retrieved'] = address['postcode'].lower() == address['parsed']['postcode']
    except:
        address['postcode_retrieved'] = False
        
    # Detect if country retrieval worked
    try:
        address['country_retrieved'] = address['country'].lower() == address['parsed']['country']
    except:
        address['country_retrieved'] = False
    
    print(address['dirty'])
# Out:
# {'postcode': 'YO24 2XQ', 'region': 'YORK', 'street_address': '9 IRVINE WAY YORK', 'country': 'UK'}
# 9 IRVINE WAY YORK YORK YO24 2XQ UK
# {'postcode': 'PO11 9SE', 'region': 'HAMPSHIRE', 'street_address': '16 TRELOAR ROAD HAYLING ISLAND', 'country': 'P.R.CHINA'}
# 16 TRELOAR ROAD HAYLING ISLAND HAMPSHIRE PO11 9SE P.R.CHINA
# {'postcode': 'HU8 8ES', 'region': 'CITY OF KINGSTON UPON HULL', 'street_address': '8 LABURNUM GROVE HULL', 'country': 'IRAN'}
# 8 LABURNUM GROVE HULL CITY OF KINGSTON UPON HULL HU8 8ES IRAN
# {'postcode': 'S81 0AB', 'region': 'NOTTINGHAMSHIRE', 'street_address': '31 QUEENSWAY WORKSOP', 'country': 'UK'}
# 31 QUEENSWAY WORKSOP NOTTINGHAMSHIRE S81 0AB UK
# {'postcode': 'TQ2 7SU', 'region': 'TORBAY', 'street_address': '105 HERON WAY TORQUAY', 'country': 'TAIWAN CHINA'}
# 105 HERON WAY TORQUAY TORBAY TQ2 7SU TAIWAN CHINA
# {'postcode': 'SY13 4AT', 'region': 'CHESHIRE EAST', 'street_address': 'BURLEYDAM HOUSE WHITCHURCH ROAD BURLEYDAM WHITCHURCH', 'country': 'U.K'}
# BURLEYDAM HOUSE WHITCHURCH ROAD BURLEYDAM WHITCHURCH CHESHIRE EAST SY13 4AT U.K
# {'postcode': 'ME14 5HW', 'region': 'KENT', 'street_address': 'PARK HOUSE FLAT 21 PARK AVENUE MAIDSTONE', 'country': 'IRAN'}
# PARK HOUSE FLAT 21 PARK AVENUE MAIDSTONE KENT ME14 5HW IRAN
# {'postcode': 'CH5 4DF', 'region': 'FLINTSHIRE', 'street_address': '98 HIGH STREET CONNAHS QUAY DEESIDE', 'country': 'U.K'}
# 98 HIGH STREET CONNAHS QUAY DEESIDE FLINTSHIRE CH5 4DF U.K
# {'postcode': 'PO9 2RR', 'region': 'HAMPSHIRE', 'street_address': '1 SOUTHLEIGH ROAD HAVANT', 'country': 'IRAN'}
# 1 SOUTHLEIGH ROAD HAVANT HAMPSHIRE PO9 2RR IRAN
# {'postcode': 'BS7 0AZ', 'region': 'CITY OF BRISTOL', 'street_address': '224 FILTON AVENUE HORFIELD BRISTOL', 'country': 'P.R.CHINA'}
# 224 FILTON AVENUE HORFIELD BRISTOL CITY OF BRISTOL BS7 0AZ P.R.CHINA
# {'postcode': 'GL2 8JU', 'region': 'GLOUCESTERSHIRE', 'street_address': 'LEY CROSSING BUNGALOW LEY LANE MINSTERWORTH GLOUCESTER', 'country': 'UK'}
# LEY CROSSING BUNGALOW LEY LANE MINSTERWORTH GLOUCESTER GLOUCESTERSHIRE GL2 8JU UK
# {'postcode': 'BH25 5NQ', 'region': 'HAMPSHIRE', 'street_address': '222 GORE ROAD NEW MILTON', 'country': 'CHINA'}
# 222 GORE ROAD NEW MILTON HAMPSHIRE BH25 5NQ CHINA
# {'postcode': 'NG4 1JX', 'region': 'NOTTINGHAMSHIRE', 'street_address': '11A HILLVIEW ROAD CARLTON NOTTINGHAM', 'country': 'UK'}
# 11A HILLVIEW ROAD CARLTON NOTTINGHAM NOTTINGHAMSHIRE NG4 1JX UK
# {'postcode': 'NG17 8PT', 'region': 'NOTTINGHAMSHIRE', 'street_address': '3 LILAC GROVE KIRKBY IN ASHFIELD NOTTINGHAM', 'country': 'INDIA'}
# 3 LILAC GROVE KIRKBY IN ASHFIELD NOTTINGHAM NOTTINGHAMSHIRE NG17 8PT INDIA
# {'postcode': 'SN12 6FU', 'region': 'WILTSHIRE', 'street_address': '20 SAXIFRAGE BANK MELKSHAM', 'country': 'IRAN'}
# 20 SAXIFRAGE BANK MELKSHAM WILTSHIRE SN12 6FU IRAN
# {'postcode': 'LL18 5WP', 'region': 'DENBIGHSHIRE', 'street_address': '1 RHODFA FLINT BODELWYDDAN RHYL', 'country': 'U.K'}
# 1 RHODFA FLINT BODELWYDDAN RHYL DENBIGHSHIRE LL18 5WP U.K
# {'postcode': 'BS16 1FN', 'region': 'SOUTH GLOUCESTERSHIRE', 'street_address': '5 LITTLE LOCKY CLOSE STOKE GIFFORD BRISTOL', 'country': 'INDIA'}
# 5 LITTLE LOCKY CLOSE STOKE GIFFORD BRISTOL SOUTH GLOUCESTERSHIRE BS16 1FN INDIA
# {'postcode': 'IP13 9BP', 'region': 'SUFFOLK', 'street_address': '31 CASTLE STREET FRAMLINGHAM WOODBRIDGE', 'country': 'U.K'}
# 31 CASTLE STREET FRAMLINGHAM WOODBRIDGE SUFFOLK IP13 9BP U.K
# {'postcode': 'IG11 7AL', 'region': 'GREATER LONDON', 'street_address': '1 ST ANNS BARKING', 'country': 'P.R.CHINA'}
# 1 ST ANNS BARKING GREATER LONDON IG11 7AL P.R.CHINA
# {'postcode': 'MK2 2FB', 'region': 'MILTON KEYNES', 'street_address': '29 PRINCES WAY BLETCHLEY MILTON KEYNES', 'country': 'INDIA'}
# 29 PRINCES WAY BLETCHLEY MILTON KEYNES MILTON KEYNES MK2 2FB INDIA
# {'postcode': 'GL50 3LW', 'region': 'GLOUCESTERSHIRE', 'street_address': '18 CHAPEL STREET CHELTENHAM', 'country': 'TAIWAN CHINA'}
# 18 CHAPEL STREET CHELTENHAM GLOUCESTERSHIRE GL50 3LW TAIWAN CHINA
# {'postcode': 'PR9 8RE', 'region': 'MERSEYSIDE', 'street_address': '20 BAYTREE CLOSE SOUTHPORT', 'country': 'INDIA'}
# 20 BAYTREE CLOSE SOUTHPORT MERSEYSIDE PR9 8RE INDIA
# {'postcode': 'RG4 7QT', 'region': 'READING', 'street_address': '280 HEMDEAN ROAD CAVERSHAM READING', 'country': 'IRAN'}
# 280 HEMDEAN ROAD CAVERSHAM READING READING RG4 7QT IRAN
# {'postcode': 'DL3 9QD', 'region': 'DARLINGTON', 'street_address': '11 LAZENBY GROVE DARLINGTON', 'country': 'U.K'}
# 11 LAZENBY GROVE DARLINGTON DARLINGTON DL3 9QD U.K
# {'postcode': 'SE16 7BW', 'region': 'GREATER LONDON', 'street_address': 'VANCOUVER HOUSE FLAT 107 NEEDLEMAN STREET LONDON', 'country': 'U.K'}
# VANCOUVER HOUSE FLAT 107 NEEDLEMAN STREET LONDON GREATER LONDON SE16 7BW U.K
# {'postcode': 'ST1 6AQ', 'region': 'STOKE-ON-TRENT', 'street_address': 'RIVERSIDE COURT APARTMENT 10 LEEK ROAD STOKE-ON-TRENT', 'country': 'U.K'}
# RIVERSIDE COURT APARTMENT 10 LEEK ROAD STOKE-ON-TRENT STOKE-ON-TRENT ST1 6AQ U.K
# {'postcode': 'SA7 9PQ', 'region': 'SWANSEA', 'street_address': '11 LLYS DWRGI BIRCHGROVE SWANSEA', 'country': 'U.K'}
# 11 LLYS DWRGI BIRCHGROVE SWANSEA SWANSEA SA7 9PQ U.K
# {'postcode': 'YO24 4DG', 'region': 'YORK', 'street_address': 'CHANCERY RISE 4 HOLGATE ROAD YORK', 'country': 'U.K'}
# CHANCERY RISE 4 HOLGATE ROAD YORK YORK YO24 4DG U.K
# {'postcode': 'M30 9JQ', 'region': 'GREATER MANCHESTER', 'street_address': '13 PARK ROAD ECCLES MANCHESTER', 'country': 'UK'}
# 13 PARK ROAD ECCLES MANCHESTER GREATER MANCHESTER M30 9JQ UK
# {'postcode': 'SW18 3QS', 'region': 'GREATER LONDON', 'street_address': '42 QUINTON STREET LONDON', 'country': 'IRAN'}
# 42 QUINTON STREET LONDON GREATER LONDON SW18 3QS IRAN
# {'postcode': 'OX13 5BP', 'region': 'OXFORDSHIRE', 'street_address': '6 STONE HOUSE CLOSE KINGSTON BAGPUIZE ABINGDON', 'country': 'INDIA'}
# 6 STONE HOUSE CLOSE KINGSTON BAGPUIZE ABINGDON OXFORDSHIRE OX13 5BP INDIA
# {'postcode': 'NE22 6JB', 'region': 'NORTHUMBERLAND', 'street_address': '10 HARTFORD CRESCENT BEDLINGTON', 'country': 'U.K'}
# 10 HARTFORD CRESCENT BEDLINGTON NORTHUMBERLAND NE22 6JB U.K
# {'postcode': 'TS3 9HF', 'region': 'MIDDLESBROUGH', 'street_address': '74 RAINSFORD CRESCENT MIDDLESBROUGH', 'country': 'IRAN'}
# 74 RAINSFORD CRESCENT MIDDLESBROUGH MIDDLESBROUGH TS3 9HF IRAN
# {'postcode': 'E4 6XS', 'region': 'GREATER LONDON', 'street_address': '59 STAPLEFORD CLOSE LONDON', 'country': 'TAIWAN CHINA'}
# 59 STAPLEFORD CLOSE LONDON GREATER LONDON E4 6XS TAIWAN CHINA
# {'postcode': 'RH6 9JA', 'region': 'SURREY', 'street_address': '20 MEADOW WAY HORLEY', 'country': 'UK'}
# 20 MEADOW WAY HORLEY SURREY RH6 9JA UK
# {'postcode': 'RH16 1PW', 'region': 'WEST SUSSEX', 'street_address': '46 PENLAND ROAD HAYWARDS HEATH', 'country': 'UK'}
# 46 PENLAND ROAD HAYWARDS HEATH WEST SUSSEX RH16 1PW UK
# {'postcode': 'CT6 6EW', 'region': 'KENT', 'street_address': '62 HERNE AVENUE HERNE BAY', 'country': 'IRAN'}
# 62 HERNE AVENUE HERNE BAY KENT CT6 6EW IRAN
# {'postcode': 'DE4 5EZ', 'region': 'DERBYSHIRE', 'street_address': 'BARLEY COTTAGES 2 THE CLIFF MATLOCK', 'country': 'CHINA'}
# BARLEY COTTAGES 2 THE CLIFF MATLOCK DERBYSHIRE DE4 5EZ CHINA
# {'postcode': 'B73 5QE', 'region': 'WEST MIDLANDS', 'street_address': '50 HIGHBRIDGE ROAD SUTTON COLDFIELD', 'country': 'UK'}
# 50 HIGHBRIDGE ROAD SUTTON COLDFIELD WEST MIDLANDS B73 5QE UK
# {'postcode': 'PE36 5PD', 'region': 'NORFOLK', 'street_address': '15 ANDREWS PLACE HUNSTANTON', 'country': 'IRAN'}
# 15 ANDREWS PLACE HUNSTANTON NORFOLK PE36 5PD IRAN
# {'postcode': 'CV7 9PW', 'region': 'WARWICKSHIRE', 'street_address': '96 TRESILLIAN ROAD EXHALL COVENTRY', 'country': 'TAIWAN CHINA'}
# 96 TRESILLIAN ROAD EXHALL COVENTRY WARWICKSHIRE CV7 9PW TAIWAN CHINA
# {'postcode': 'RG2 7HA', 'region': 'READING', 'street_address': '28A NORTHCOURT AVENUE READING', 'country': 'IRAN'}
# 28A NORTHCOURT AVENUE READING READING RG2 7HA IRAN
# {'postcode': 'PE13 5HA', 'region': 'CAMBRIDGESHIRE', 'street_address': 'ARIES FERRY LANE NEWTON WISBECH', 'country': 'UK'}
# ARIES FERRY LANE NEWTON WISBECH CAMBRIDGESHIRE PE13 5HA UK
# {'postcode': 'WR15 8LB', 'region': 'SHROPSHIRE', 'street_address': 'WOODLANDS ARCHERS WAY BURFORD TENBURY WELLS', 'country': 'U.K'}
# WOODLANDS ARCHERS WAY BURFORD TENBURY WELLS SHROPSHIRE WR15 8LB U.K
# {'postcode': 'BN6 9JR', 'region': 'WEST SUSSEX', 'street_address': '6 OSBORN CLOSE SAYERS COMMON HASSOCKS', 'country': 'UK'}
# 6 OSBORN CLOSE SAYERS COMMON HASSOCKS WEST SUSSEX BN6 9JR UK
# {'postcode': 'SW19 1SS', 'region': 'GREATER LONDON', 'street_address': 'CLOISTERS HOUSE, 53 FLAT 20 GRIFFITHS ROAD LONDON', 'country': 'TAIWAN CHINA'}
# CLOISTERS HOUSE, 53 FLAT 20 GRIFFITHS ROAD LONDON GREATER LONDON SW19 1SS TAIWAN CHINA
# {'postcode': 'BS35 2DY', 'region': 'SOUTH GLOUCESTERSHIRE', 'street_address': '34 DOVEDALE THORNBURY BRISTOL', 'country': 'U.K'}
# 34 DOVEDALE THORNBURY BRISTOL SOUTH GLOUCESTERSHIRE BS35 2DY U.K
# {'postcode': 'S9 3DJ', 'region': 'SOUTH YORKSHIRE', 'street_address': '18 FAY CRESCENT SHEFFIELD', 'country': 'UK'}
# 18 FAY CRESCENT SHEFFIELD SOUTH YORKSHIRE S9 3DJ UK
# {'postcode': 'DA3 7HJ', 'region': 'KENT', 'street_address': '16 FERNDENE LONGFIELD', 'country': 'INDIA'}
# 16 FERNDENE LONGFIELD KENT DA3 7HJ INDIA
# {'postcode': 'SE18 6FE', 'region': 'GREATER LONDON', 'street_address': 'WAREHOUSE COURT FLAT 176 MAJOR DRAPER STREET LONDON', 'country': 'U.K'}
# WAREHOUSE COURT FLAT 176 MAJOR DRAPER STREET LONDON GREATER LONDON SE18 6FE U.K
# {'postcode': 'BN22 8XJ', 'region': 'EAST SUSSEX', 'street_address': '25 MAYFIELD PLACE EASTBOURNE', 'country': 'UK'}
# 25 MAYFIELD PLACE EASTBOURNE EAST SUSSEX BN22 8XJ UK
# {'postcode': 'LS6 4SE', 'region': 'WEST YORKSHIRE', 'street_address': '34 WOODLEA GARDENS MEANWOOD LEEDS', 'country': 'U.K'}
# 34 WOODLEA GARDENS MEANWOOD LEEDS WEST YORKSHIRE LS6 4SE U.K
# {'postcode': 'RG30 2HT', 'region': 'READING', 'street_address': '49 ELM PARK READING', 'country': 'U.K'}
# 49 ELM PARK READING READING RG30 2HT U.K
# {'postcode': 'KT6 4AW', 'region': 'GREATER LONDON', 'street_address': '99 FLAT 2 MAPLE ROAD SURBITON', 'country': 'CHINA'}
# 99 FLAT 2 MAPLE ROAD SURBITON GREATER LONDON KT6 4AW CHINA
# {'postcode': 'RH16 4ER', 'region': 'WEST SUSSEX', 'street_address': '8 REDWOOD DRIVE HAYWARDS HEATH', 'country': 'UK'}
# 8 REDWOOD DRIVE HAYWARDS HEATH WEST SUSSEX RH16 4ER UK
# {'postcode': 'CO4 9GD', 'region': 'ESSEX', 'street_address': '5 ALVERTON WAY HIGHWOODS COLCHESTER', 'country': 'CHINA'}
# 5 ALVERTON WAY HIGHWOODS COLCHESTER ESSEX CO4 9GD CHINA
# {'postcode': 'LS16 7RJ', 'region': 'WEST YORKSHIRE', 'street_address': '20 HOLTDALE PLACE LEEDS', 'country': 'P.R.CHINA'}
# 20 HOLTDALE PLACE LEEDS WEST YORKSHIRE LS16 7RJ P.R.CHINA
# {'postcode': 'YO15 3HS', 'region': 'EAST RIDING OF YORKSHIRE', 'street_address': '46 NEW BURLINGTON ROAD BRIDLINGTON', 'country': 'UK'}
# 46 NEW BURLINGTON ROAD BRIDLINGTON EAST RIDING OF YORKSHIRE YO15 3HS UK
# {'postcode': 'RH5 4SG', 'region': 'SURREY', 'street_address': '40 OAK CORNER BEARE GREEN DORKING', 'country': 'TAIWAN CHINA'}
# 40 OAK CORNER BEARE GREEN DORKING SURREY RH5 4SG TAIWAN CHINA
# {'postcode': 'ST4 8FJ', 'region': 'STOKE-ON-TRENT', 'street_address': '87 EDGBASTON DRIVE STOKE-ON-TRENT', 'country': 'TAIWAN CHINA'}
# 87 EDGBASTON DRIVE STOKE-ON-TRENT STOKE-ON-TRENT ST4 8FJ TAIWAN CHINA
# {'postcode': 'CH48 3HR', 'region': 'MERSEYSIDE', 'street_address': '12 HYDRO AVENUE WIRRAL', 'country': 'U.K'}
# 12 HYDRO AVENUE WIRRAL MERSEYSIDE CH48 3HR U.K
# {'postcode': 'CF14 2TJ', 'region': 'CARDIFF', 'street_address': 'GLENDOWER COURT FLAT 4 VELINDRE ROAD CARDIFF', 'country': 'INDIA'}
# GLENDOWER COURT FLAT 4 VELINDRE ROAD CARDIFF CARDIFF CF14 2TJ INDIA
# {'postcode': 'NG5 7EZ', 'region': 'NOTTINGHAMSHIRE', 'street_address': '34 BENTWELL AVENUE ARNOLD NOTTINGHAM', 'country': 'INDIA'}
# 34 BENTWELL AVENUE ARNOLD NOTTINGHAM NOTTINGHAMSHIRE NG5 7EZ INDIA
# {'postcode': 'BH3 7JZ', 'region': 'BOURNEMOUTH', 'street_address': '20 FLAT 2 GERALD ROAD BOURNEMOUTH', 'country': 'CHINA'}
# 20 FLAT 2 GERALD ROAD BOURNEMOUTH BOURNEMOUTH BH3 7JZ CHINA
# {'postcode': 'DA15 9HA', 'region': 'GREATER LONDON', 'street_address': '42 PORTLAND AVENUE SIDCUP', 'country': 'U.K'}
# 42 PORTLAND AVENUE SIDCUP GREATER LONDON DA15 9HA U.K
# {'postcode': 'DE22 4DH', 'region': 'CITY OF DERBY', 'street_address': '53 ENFIELD ROAD DERBY', 'country': 'U.K'}
# 53 ENFIELD ROAD DERBY CITY OF DERBY DE22 4DH U.K
# {'postcode': 'MK18 1DW', 'region': 'BUCKINGHAMSHIRE', 'street_address': '7 MITRE STREET BUCKINGHAM', 'country': 'U.K'}
# 7 MITRE STREET BUCKINGHAM BUCKINGHAMSHIRE MK18 1DW U.K
# {'postcode': 'W1W 6DP', 'region': 'GREATER LONDON', 'street_address': 'QUANTOCK HOUSE, 20 FLAT 4 FOLEY STREET LONDON', 'country': 'INDIA'}
# QUANTOCK HOUSE, 20 FLAT 4 FOLEY STREET LONDON GREATER LONDON W1W 6DP INDIA
# {'postcode': 'CA2 6LF', 'region': 'CUMBRIA', 'street_address': '56 WESTRIGG ROAD CARLISLE', 'country': 'TAIWAN CHINA'}
# 56 WESTRIGG ROAD CARLISLE CUMBRIA CA2 6LF TAIWAN CHINA
# {'postcode': 'CO16 9PZ', 'region': 'ESSEX', 'street_address': '283 HARWICH ROAD LITTLE CLACTON CLACTON-ON-SEA', 'country': 'IRAN'}
# 283 HARWICH ROAD LITTLE CLACTON CLACTON-ON-SEA ESSEX CO16 9PZ IRAN
# {'postcode': 'PO13 9SE', 'region': 'HAMPSHIRE', 'street_address': '27 HENVILLE CLOSE ROWNER GOSPORT', 'country': 'CHINA'}
# 27 HENVILLE CLOSE ROWNER GOSPORT HAMPSHIRE PO13 9SE CHINA
# {'postcode': 'TN13 1JE', 'region': 'KENT', 'street_address': '4 SIX BELLS LANE SEVENOAKS', 'country': 'U.K'}
# 4 SIX BELLS LANE SEVENOAKS KENT TN13 1JE U.K
# {'postcode': 'B30 2JA', 'region': 'WEST MIDLANDS', 'street_address': '2 SHIRLEY ROAD KINGS NORTON BIRMINGHAM', 'country': 'IRAN'}
# 2 SHIRLEY ROAD KINGS NORTON BIRMINGHAM WEST MIDLANDS B30 2JA IRAN
# {'postcode': 'SA6 7EG', 'region': 'SWANSEA', 'street_address': '26 LON CAMLAD MORRISTON SWANSEA', 'country': 'TAIWAN CHINA'}
# 26 LON CAMLAD MORRISTON SWANSEA SWANSEA SA6 7EG TAIWAN CHINA
# {'postcode': 'TS25 5BJ', 'region': 'HARTLEPOOL', 'street_address': '60 HASWELL AVENUE HARTLEPOOL', 'country': 'CHINA'}
# 60 HASWELL AVENUE HARTLEPOOL HARTLEPOOL TS25 5BJ CHINA
# {'postcode': 'WA5 1EZ', 'region': 'WARRINGTON', 'street_address': '7 THURSTON CLOSE GREAT SANKEY WARRINGTON', 'country': 'INDIA'}
# 7 THURSTON CLOSE GREAT SANKEY WARRINGTON WARRINGTON WA5 1EZ INDIA
# {'postcode': 'LE17 6LR', 'region': 'LEICESTERSHIRE', 'street_address': '16 MOWSLEY ROAD HUSBANDS BOSWORTH LUTTERWORTH', 'country': 'CHINA'}
# 16 MOWSLEY ROAD HUSBANDS BOSWORTH LUTTERWORTH LEICESTERSHIRE LE17 6LR CHINA
# {'postcode': 'LL36 9DY', 'region': 'GWYNEDD', 'street_address': '14 BRYN HEULOG TYWYN', 'country': 'U.K'}
# 14 BRYN HEULOG TYWYN GWYNEDD LL36 9DY U.K
# {'postcode': 'CF39 9LF', 'region': 'RHONDDA CYNON TAFF', 'street_address': '45 GLYNFACH ROAD PORTH', 'country': 'CHINA'}
# 45 GLYNFACH ROAD PORTH RHONDDA CYNON TAFF CF39 9LF CHINA
# {'postcode': 'SW18 4QL', 'region': 'GREATER LONDON', 'street_address': '30 DUNTSHILL ROAD LONDON', 'country': 'U.K'}
# 30 DUNTSHILL ROAD LONDON GREATER LONDON SW18 4QL U.K
# {'postcode': 'SN3 1JZ', 'region': 'SWINDON', 'street_address': '10 WARDOUR CLOSE SWINDON', 'country': 'U.K'}
# 10 WARDOUR CLOSE SWINDON SWINDON SN3 1JZ U.K
# {'postcode': 'E3 3GU', 'region': 'GREATER LONDON', 'street_address': 'ALBORAN APARTMENTS, 1 FLAT 302 SEVEN SEA GARDENS LONDON', 'country': 'UK'}
# ALBORAN APARTMENTS, 1 FLAT 302 SEVEN SEA GARDENS LONDON GREATER LONDON E3 3GU UK
# {'postcode': 'CB6 1DE', 'region': 'CAMBRIDGESHIRE', 'street_address': '56 LYNN ROAD ELY', 'country': 'TAIWAN CHINA'}
# 56 LYNN ROAD ELY CAMBRIDGESHIRE CB6 1DE TAIWAN CHINA
# {'postcode': 'IP31 3PJ', 'region': 'SUFFOLK', 'street_address': 'WESTCOMBE HEATH ROAD THURSTON BURY ST EDMUNDS', 'country': 'U.K'}
# WESTCOMBE HEATH ROAD THURSTON BURY ST EDMUNDS SUFFOLK IP31 3PJ U.K
# {'postcode': 'WR11 8TH', 'region': 'WORCESTERSHIRE', 'street_address': 'OBEM LONG HYDE ROAD SOUTH LITTLETON EVESHAM', 'country': 'UK'}
# OBEM LONG HYDE ROAD SOUTH LITTLETON EVESHAM WORCESTERSHIRE WR11 8TH UK
# {'postcode': 'CH43 7QE', 'region': 'MERSEYSIDE', 'street_address': '143 UPTON ROAD PRENTON', 'country': 'CHINA'}
# 143 UPTON ROAD PRENTON MERSEYSIDE CH43 7QE CHINA
# {'postcode': 'TN4 9SB', 'region': 'KENT', 'street_address': '13 CULVERDEN DOWN TUNBRIDGE WELLS', 'country': 'TAIWAN CHINA'}
# 13 CULVERDEN DOWN TUNBRIDGE WELLS KENT TN4 9SB TAIWAN CHINA
# {'postcode': 'TW17 0EX', 'region': 'SURREY', 'street_address': '54 WATERSPLASH ROAD SHEPPERTON', 'country': 'P.R.CHINA'}
# 54 WATERSPLASH ROAD SHEPPERTON SURREY TW17 0EX P.R.CHINA
# {'postcode': 'WF7 7BB', 'region': 'WEST YORKSHIRE', 'street_address': '13 GARDEN STREET ACKWORTH PONTEFRACT', 'country': 'INDIA'}
# 13 GARDEN STREET ACKWORTH PONTEFRACT WEST YORKSHIRE WF7 7BB INDIA
# {'postcode': 'SM6 7LJ', 'region': 'GREATER LONDON', 'street_address': '10 BERKELEY COURT WALLINGTON', 'country': 'INDIA'}
# 10 BERKELEY COURT WALLINGTON GREATER LONDON SM6 7LJ INDIA
# {'postcode': 'RH20 1DZ', 'region': 'WEST SUSSEX', 'street_address': '17 MASONS WAY CODMORE HILL PULBOROUGH', 'country': 'UK'}
# 17 MASONS WAY CODMORE HILL PULBOROUGH WEST SUSSEX RH20 1DZ UK
# {'postcode': 'LE16 9DA', 'region': 'LEICESTERSHIRE', 'street_address': '130 COVENTRY ROAD MARKET HARBOROUGH', 'country': 'U.K'}
# 130 COVENTRY ROAD MARKET HARBOROUGH LEICESTERSHIRE LE16 9DA U.K
# {'postcode': 'HP18 0FG', 'region': 'BUCKINGHAMSHIRE', 'street_address': '6 JOHN FITZJOHN AVENUE AYLESBURY', 'country': 'U.K'}
# 6 JOHN FITZJOHN AVENUE AYLESBURY BUCKINGHAMSHIRE HP18 0FG U.K
# {'postcode': 'NN12 6UQ', 'region': 'NORTHAMPTONSHIRE', 'street_address': '83 HAZEL CRESCENT TOWCESTER', 'country': 'U.K'}
# 83 HAZEL CRESCENT TOWCESTER NORTHAMPTONSHIRE NN12 6UQ U.K
# {'postcode': 'NP7 6HN', 'region': 'MONMOUTHSHIRE', 'street_address': '74 ST ANDREWS CRESCENT ABERGAVENNY', 'country': 'UK'}
# 74 ST ANDREWS CRESCENT ABERGAVENNY MONMOUTHSHIRE NP7 6HN UK
# {'postcode': 'WR4 0QW', 'region': 'WORCESTERSHIRE', 'street_address': '6 HUNT AVENUE WORCESTER', 'country': 'P.R.CHINA'}
# 6 HUNT AVENUE WORCESTER WORCESTERSHIRE WR4 0QW P.R.CHINA
# {'postcode': 'GU9 0NW', 'region': 'SURREY', 'street_address': 'TANGLEWOOD OAST HOUSE LANE FARNHAM', 'country': 'CHINA'}
# TANGLEWOOD OAST HOUSE LANE FARNHAM SURREY GU9 0NW CHINA
# {'postcode': 'SN3 4GL', 'region': 'SWINDON', 'street_address': '4 STATION HALT SWINDON', 'country': 'P.R.CHINA'}
# 4 STATION HALT SWINDON SWINDON SN3 4GL P.R.CHINA
# {'postcode': 'NG9 7DZ', 'region': 'NOTTINGHAMSHIRE', 'street_address': '1 TUDOR COURT STAPLEFORD NOTTINGHAM', 'country': 'IRAN'}
# 1 TUDOR COURT STAPLEFORD NOTTINGHAM NOTTINGHAMSHIRE NG9 7DZ IRAN
# {'postcode': 'RG30 4PB', 'region': 'READING', 'street_address': '312 THE MEADWAY TILEHURST READING', 'country': 'UK'}
# 312 THE MEADWAY TILEHURST READING READING RG30 4PB UK
# {'postcode': 'SW4 0PE', 'region': 'GREATER LONDON', 'street_address': '119 VICTORIA RISE LONDON', 'country': 'UK'}
# 119 VICTORIA RISE LONDON GREATER LONDON SW4 0PE UK
# {'postcode': 'S71 4FN', 'region': 'SOUTH YORKSHIRE', 'street_address': '16 MELTON WAY ROYSTON BARNSLEY', 'country': 'UK'}
# 16 MELTON WAY ROYSTON BARNSLEY SOUTH YORKSHIRE S71 4FN UK
# {'postcode': 'DE65 5NL', 'region': 'DERBYSHIRE', 'street_address': '49 EDEN CLOSE HILTON DERBY', 'country': 'TAIWAN CHINA'}
# 49 EDEN CLOSE HILTON DERBY DERBYSHIRE DE65 5NL TAIWAN CHINA
# {'postcode': 'CF15 9TA', 'region': 'CARDIFF', 'street_address': '39 BRON HAUL PENTYRCH CARDIFF', 'country': 'P.R.CHINA'}
# 39 BRON HAUL PENTYRCH CARDIFF CARDIFF CF15 9TA P.R.CHINA
# {'postcode': 'IG9 5FE', 'region': 'ESSEX', 'street_address': '100 BROOK ROAD BUCKHURST HILL', 'country': 'TAIWAN CHINA'}
# 100 BROOK ROAD BUCKHURST HILL ESSEX IG9 5FE TAIWAN CHINA
# {'postcode': 'PO16 9DQ', 'region': 'HAMPSHIRE', 'street_address': '6 BRENCHLEY CLOSE FAREHAM', 'country': 'U.K'}
# 6 BRENCHLEY CLOSE FAREHAM HAMPSHIRE PO16 9DQ U.K
# {'postcode': 'RM15 4AD', 'region': 'THURROCK', 'street_address': '20 HIGH STREET AVELEY SOUTH OCKENDON', 'country': 'UK'}
# 20 HIGH STREET AVELEY SOUTH OCKENDON THURROCK RM15 4AD UK
# {'postcode': 'ME17 4DG', 'region': 'KENT', 'street_address': '14 WESTERHILL ROAD COXHEATH MAIDSTONE', 'country': 'CHINA'}
# 14 WESTERHILL ROAD COXHEATH MAIDSTONE KENT ME17 4DG CHINA
# {'postcode': 'NN29 7JS', 'region': 'NORTHAMPTONSHIRE', 'street_address': '16 BOSGATE CLOSE BOZEAT WELLINGBOROUGH', 'country': 'TAIWAN CHINA'}
# 16 BOSGATE CLOSE BOZEAT WELLINGBOROUGH NORTHAMPTONSHIRE NN29 7JS TAIWAN CHINA
# {'postcode': 'N10 1QG', 'region': 'GREATER LONDON', 'street_address': 'BARRINGTON COURT FLAT 7 COLNEY HATCH LANE LONDON', 'country': 'CHINA'}
# BARRINGTON COURT FLAT 7 COLNEY HATCH LANE LONDON GREATER LONDON N10 1QG CHINA
# {'postcode': 'CB8 0AY', 'region': 'SUFFOLK', 'street_address': '193 EXNING ROAD NEWMARKET', 'country': 'UK'}
# 193 EXNING ROAD NEWMARKET SUFFOLK CB8 0AY UK
# {'postcode': 'LN6 0NT', 'region': 'LINCOLNSHIRE', 'street_address': '5 LECONFIELD ROAD LINCOLN', 'country': 'P.R.CHINA'}
# 5 LECONFIELD ROAD LINCOLN LINCOLNSHIRE LN6 0NT P.R.CHINA
# {'postcode': 'KT8 9DE', 'region': 'SURREY', 'street_address': 'ANN BOLEYN HOUSE FLAT 23 QUEENS REACH EAST MOLESEY', 'country': 'CHINA'}
# ANN BOLEYN HOUSE FLAT 23 QUEENS REACH EAST MOLESEY SURREY KT8 9DE CHINA
# {'postcode': 'N6 5UG', 'region': 'GREATER LONDON', 'street_address': '14C MUSWELL HILL ROAD LONDON', 'country': 'U.K'}
# 14C MUSWELL HILL ROAD LONDON GREATER LONDON N6 5UG U.K
# {'postcode': 'SW8 3JG', 'region': 'GREATER LONDON', 'street_address': '771 WANDSWORTH ROAD LONDON', 'country': 'CHINA'}
# 771 WANDSWORTH ROAD LONDON GREATER LONDON SW8 3JG CHINA
# {'postcode': 'HD8 0TX', 'region': 'WEST YORKSHIRE', 'street_address': 'LINFIT MILL, 16 FLAT 5 LINFIT LANE KIRKBURTON HUDDERSFIELD', 'country': 'U.K'}
# LINFIT MILL, 16 FLAT 5 LINFIT LANE KIRKBURTON HUDDERSFIELD WEST YORKSHIRE HD8 0TX U.K
# {'postcode': 'WV6 8AF', 'region': 'WEST MIDLANDS', 'street_address': '71 BRIDGNORTH ROAD WOLVERHAMPTON', 'country': 'U.K'}
# 71 BRIDGNORTH ROAD WOLVERHAMPTON WEST MIDLANDS WV6 8AF U.K
# {'postcode': 'KT16 9GU', 'region': 'SURREY', 'street_address': 'LIBERTY HOUSE FLAT 6 GUILDFORD STREET CHERTSEY', 'country': 'IRAN'}
# LIBERTY HOUSE FLAT 6 GUILDFORD STREET CHERTSEY SURREY KT16 9GU IRAN
# {'postcode': 'BL6 7BY', 'region': 'GREATER MANCHESTER', 'street_address': '2 LEE LANE HORWICH BOLTON', 'country': 'TAIWAN CHINA'}
# 2 LEE LANE HORWICH BOLTON GREATER MANCHESTER BL6 7BY TAIWAN CHINA
# {'postcode': 'B26 3AR', 'region': 'WEST MIDLANDS', 'street_address': '57 BEECHMORE ROAD BIRMINGHAM', 'country': 'UK'}
# 57 BEECHMORE ROAD BIRMINGHAM WEST MIDLANDS B26 3AR UK
# {'postcode': 'OX7 5DN', 'region': 'OXFORDSHIRE', 'street_address': '3 WALTERBUSH ROAD CHIPPING NORTON', 'country': 'TAIWAN CHINA'}
# 3 WALTERBUSH ROAD CHIPPING NORTON OXFORDSHIRE OX7 5DN TAIWAN CHINA
# {'postcode': 'E9 5FA', 'region': 'GREATER LONDON', 'street_address': 'SKY APARTMENTS FLAT 42 HOMERTON ROAD LONDON', 'country': 'TAIWAN CHINA'}
# SKY APARTMENTS FLAT 42 HOMERTON ROAD LONDON GREATER LONDON E9 5FA TAIWAN CHINA
# {'postcode': 'PL26 8UP', 'region': 'CORNWALL', 'street_address': '4 PENHALE ROAD PENWITHICK ST AUSTELL', 'country': 'IRAN'}
# 4 PENHALE ROAD PENWITHICK ST AUSTELL CORNWALL PL26 8UP IRAN
# {'postcode': 'BS37 7YJ', 'region': 'SOUTH GLOUCESTERSHIRE', 'street_address': '20 HAY LEAZE YATE BRISTOL', 'country': 'U.K'}
# 20 HAY LEAZE YATE BRISTOL SOUTH GLOUCESTERSHIRE BS37 7YJ U.K
# {'postcode': 'SG19 3RL', 'region': 'CAMBRIDGESHIRE', 'street_address': '23 AUDLEY CLOSE GREAT GRANSDEN SANDY', 'country': 'IRAN'}
# 23 AUDLEY CLOSE GREAT GRANSDEN SANDY CAMBRIDGESHIRE SG19 3RL IRAN
# {'postcode': 'NG4 3PU', 'region': 'NOTTINGHAMSHIRE', 'street_address': '8 MARWOOD ROAD CARLTON NOTTINGHAM', 'country': 'UK'}
# 8 MARWOOD ROAD CARLTON NOTTINGHAM NOTTINGHAMSHIRE NG4 3PU UK
# {'postcode': 'LL46 2SL', 'region': 'GWYNEDD', 'street_address': '2 PENYBRYN ESTATE HARLECH', 'country': 'INDIA'}
# 2 PENYBRYN ESTATE HARLECH GWYNEDD LL46 2SL INDIA
# {'postcode': 'SE18 6FB', 'region': 'GREATER LONDON', 'street_address': 'WAREHOUSE COURT FLAT 11 NO 1 STREET LONDON', 'country': 'P.R.CHINA'}
# WAREHOUSE COURT FLAT 11 NO 1 STREET LONDON GREATER LONDON SE18 6FB P.R.CHINA
# {'postcode': 'SA73 3JU', 'region': 'PEMBROKESHIRE', 'street_address': 'THE VICARAGE SANDHURST ROAD MILFORD HAVEN', 'country': 'CHINA'}
# THE VICARAGE SANDHURST ROAD MILFORD HAVEN PEMBROKESHIRE SA73 3JU CHINA
# {'postcode': 'N17 6UJ', 'region': 'GREATER LONDON', 'street_address': '103 SPERLING ROAD LONDON', 'country': 'INDIA'}
# 103 SPERLING ROAD LONDON GREATER LONDON N17 6UJ INDIA
# {'postcode': 'OX27 9BJ', 'region': 'OXFORDSHIRE', 'street_address': 'MANOR COTTAGE MILL ROAD STRATTON AUDLEY BICESTER', 'country': 'TAIWAN CHINA'}
# MANOR COTTAGE MILL ROAD STRATTON AUDLEY BICESTER OXFORDSHIRE OX27 9BJ TAIWAN CHINA
# {'postcode': 'NN14 1BY', 'region': 'NORTHAMPTONSHIRE', 'street_address': '21 CARDIGAN ROAD STANION KETTERING', 'country': 'P.R.CHINA'}
# 21 CARDIGAN ROAD STANION KETTERING NORTHAMPTONSHIRE NN14 1BY P.R.CHINA
# {'postcode': 'PO38 1XT', 'region': 'ISLE OF WIGHT', 'street_address': 'MADEIRA HUNTS ROAD ST LAWRENCE VENTNOR', 'country': 'U.K'}
# MADEIRA HUNTS ROAD ST LAWRENCE VENTNOR ISLE OF WIGHT PO38 1XT U.K
# {'postcode': 'PR7 4RL', 'region': 'LANCASHIRE', 'street_address': '28 CARRINGTON ROAD ADLINGTON CHORLEY', 'country': 'P.R.CHINA'}
# 28 CARRINGTON ROAD ADLINGTON CHORLEY LANCASHIRE PR7 4RL P.R.CHINA
# {'postcode': 'S63 0AU', 'region': 'SOUTH YORKSHIRE', 'street_address': '21 ACORN AVENUE THURNSCOE ROTHERHAM', 'country': 'CHINA'}
# 21 ACORN AVENUE THURNSCOE ROTHERHAM SOUTH YORKSHIRE S63 0AU CHINA
# {'postcode': 'E18 2QA', 'region': 'GREATER LONDON', 'street_address': '68 FULLERS ROAD LONDON', 'country': 'IRAN'}
# 68 FULLERS ROAD LONDON GREATER LONDON E18 2QA IRAN
# {'postcode': 'PE9 1BS', 'region': 'LINCOLNSHIRE', 'street_address': '14 PEMBROKE ROAD STAMFORD', 'country': 'INDIA'}
# 14 PEMBROKE ROAD STAMFORD LINCOLNSHIRE PE9 1BS INDIA
# {'postcode': 'BS24 9NQ', 'region': 'NORTH SOMERSET', 'street_address': '4 MAIDSTONE GROVE WESTON-SUPER-MARE', 'country': 'UK'}
# 4 MAIDSTONE GROVE WESTON-SUPER-MARE NORTH SOMERSET BS24 9NQ UK
# {'postcode': 'MK43 7BP', 'region': 'BEDFORD', 'street_address': '49 ORCHARD LANE HARROLD BEDFORD', 'country': 'U.K'}
# 49 ORCHARD LANE HARROLD BEDFORD BEDFORD MK43 7BP U.K
# {'postcode': 'EX32 9LW', 'region': 'DEVON', 'street_address': '77 HUGHES AVENUE BARNSTAPLE', 'country': 'TAIWAN CHINA'}
# 77 HUGHES AVENUE BARNSTAPLE DEVON EX32 9LW TAIWAN CHINA
# {'postcode': 'PE15 0ST', 'region': 'CAMBRIDGESHIRE', 'street_address': 'BYWAYS PRIMROSE HILL DODDINGTON MARCH', 'country': 'CHINA'}
# BYWAYS PRIMROSE HILL DODDINGTON MARCH CAMBRIDGESHIRE PE15 0ST CHINA
# {'postcode': 'CB6 1AY', 'region': 'CAMBRIDGESHIRE', 'street_address': '2 HILLS LANE ELY', 'country': 'TAIWAN CHINA'}
# 2 HILLS LANE ELY CAMBRIDGESHIRE CB6 1AY TAIWAN CHINA
# {'postcode': 'N22 7UY', 'region': 'GREATER LONDON', 'street_address': '2 YEWTREE CLOSE LONDON', 'country': 'U.K'}
# 2 YEWTREE CLOSE LONDON GREATER LONDON N22 7UY U.K
# {'postcode': 'SO30 2RL', 'region': 'HAMPSHIRE', 'street_address': '6 WALKER GARDENS HEDGE END SOUTHAMPTON', 'country': 'P.R.CHINA'}
# 6 WALKER GARDENS HEDGE END SOUTHAMPTON HAMPSHIRE SO30 2RL P.R.CHINA
# {'postcode': 'BR1 3LX', 'region': 'GREATER LONDON', 'street_address': '20 FLAT 1 GARDEN ROAD BROMLEY', 'country': 'IRAN'}
# 20 FLAT 1 GARDEN ROAD BROMLEY GREATER LONDON BR1 3LX IRAN
# {'postcode': 'E8 4NR', 'region': 'GREATER LONDON', 'street_address': '52 BROWNLOW ROAD LONDON', 'country': 'UK'}
# 52 BROWNLOW ROAD LONDON GREATER LONDON E8 4NR UK
# {'postcode': 'CB7 4UN', 'region': 'CAMBRIDGESHIRE', 'street_address': 'SALIX MAIN STREET PRICKWILLOW ELY', 'country': 'UK'}
# SALIX MAIN STREET PRICKWILLOW ELY CAMBRIDGESHIRE CB7 4UN UK
# {'postcode': 'SK8 2LQ', 'region': 'GREATER MANCHESTER', 'street_address': '22 ARGYLL ROAD CHEADLE', 'country': 'U.K'}
# 22 ARGYLL ROAD CHEADLE GREATER MANCHESTER SK8 2LQ U.K
# {'postcode': 'BA14 7TG', 'region': 'WILTSHIRE', 'street_address': '76 LACOCK GARDENS HILPERTON TROWBRIDGE', 'country': 'INDIA'}
# 76 LACOCK GARDENS HILPERTON TROWBRIDGE WILTSHIRE BA14 7TG INDIA
# {'postcode': 'TW9 2HN', 'region': 'GREATER LONDON', 'street_address': '4 STANMORE GARDENS RICHMOND', 'country': 'INDIA'}
# 4 STANMORE GARDENS RICHMOND GREATER LONDON TW9 2HN INDIA
# {'postcode': 'SO31 5AG', 'region': 'HAMPSHIRE', 'street_address': '3 LATELIE CLOSE NETLEY ABBEY SOUTHAMPTON', 'country': 'CHINA'}
# 3 LATELIE CLOSE NETLEY ABBEY SOUTHAMPTON HAMPSHIRE SO31 5AG CHINA
# {'postcode': 'SL5 9DJ', 'region': 'WINDSOR AND MAIDENHEAD', 'street_address': '7 BROCKENHURST ROAD ASCOT', 'country': 'TAIWAN CHINA'}
# 7 BROCKENHURST ROAD ASCOT WINDSOR AND MAIDENHEAD SL5 9DJ TAIWAN CHINA
# {'postcode': 'CF62 8AZ', 'region': 'THE VALE OF GLAMORGAN', 'street_address': '43 TYNEWYDD ROAD BARRY', 'country': 'U.K'}
# 43 TYNEWYDD ROAD BARRY THE VALE OF GLAMORGAN CF62 8AZ U.K
# {'postcode': 'B92 0BB', 'region': 'WEST MIDLANDS', 'street_address': '30 FENTHAM ROAD HAMPTON IN ARDEN SOLIHULL', 'country': 'U.K'}
# 30 FENTHAM ROAD HAMPTON IN ARDEN SOLIHULL WEST MIDLANDS B92 0BB U.K
# {'postcode': 'NN14 1AY', 'region': 'NORTHAMPTONSHIRE', 'street_address': '25 QUEEN ELEANOR ROAD GEDDINGTON KETTERING', 'country': 'CHINA'}
# 25 QUEEN ELEANOR ROAD GEDDINGTON KETTERING NORTHAMPTONSHIRE NN14 1AY CHINA
# {'postcode': 'S75 2QU', 'region': 'SOUTH YORKSHIRE', 'street_address': '7 WILSDEN GROVE BARNSLEY', 'country': 'UK'}
# 7 WILSDEN GROVE BARNSLEY SOUTH YORKSHIRE S75 2QU UK
# {'postcode': 'DN20 8BX', 'region': 'NORTH LINCOLNSHIRE', 'street_address': '2 ST HELENS ROAD BRIGG', 'country': 'P.R.CHINA'}
# 2 ST HELENS ROAD BRIGG NORTH LINCOLNSHIRE DN20 8BX P.R.CHINA
# {'postcode': 'CT9 3TJ', 'region': 'KENT', 'street_address': '173 MILLMEAD ROAD MARGATE', 'country': 'UK'}
# 173 MILLMEAD ROAD MARGATE KENT CT9 3TJ UK
# {'postcode': 'GL20 6FL', 'region': 'GLOUCESTERSHIRE', 'street_address': 'AVON COTTAGE FLEET LANE TWYNING TEWKESBURY', 'country': 'U.K'}
# AVON COTTAGE FLEET LANE TWYNING TEWKESBURY GLOUCESTERSHIRE GL20 6FL U.K
# {'postcode': 'HD3 3LD', 'region': 'WEST YORKSHIRE', 'street_address': '23 WEATHERHILL ROAD HUDDERSFIELD', 'country': 'IRAN'}
# 23 WEATHERHILL ROAD HUDDERSFIELD WEST YORKSHIRE HD3 3LD IRAN
# {'postcode': 'DE14 2QJ', 'region': 'STAFFORDSHIRE', 'street_address': '5 BLAKEHOLME COURT BURTON-ON-TRENT', 'country': 'TAIWAN CHINA'}
# 5 BLAKEHOLME COURT BURTON-ON-TRENT STAFFORDSHIRE DE14 2QJ TAIWAN CHINA
# {'postcode': 'SW12 9LQ', 'region': 'GREATER LONDON', 'street_address': '84 DAGNAN ROAD LONDON', 'country': 'INDIA'}
# 84 DAGNAN ROAD LONDON GREATER LONDON SW12 9LQ INDIA
# {'postcode': 'ME16 0BA', 'region': 'KENT', 'street_address': '10 HAZEL AVENUE MAIDSTONE', 'country': 'TAIWAN CHINA'}
# 10 HAZEL AVENUE MAIDSTONE KENT ME16 0BA TAIWAN CHINA
# {'postcode': 'SS17 9HT', 'region': 'THURROCK', 'street_address': 'CHY-AN-DOUR HIGH ROAD FOBBING STANFORD-LE-HOPE', 'country': 'INDIA'}
# CHY-AN-DOUR HIGH ROAD FOBBING STANFORD-LE-HOPE THURROCK SS17 9HT INDIA
# {'postcode': 'S70 6HP', 'region': 'SOUTH YORKSHIRE', 'street_address': '24 WESTBOURNE TERRACE BARNSLEY', 'country': 'U.K'}
# 24 WESTBOURNE TERRACE BARNSLEY SOUTH YORKSHIRE S70 6HP U.K
# {'postcode': 'LE16 7JR', 'region': 'LEICESTERSHIRE', 'street_address': '19 HEYGATE STREET MARKET HARBOROUGH', 'country': 'TAIWAN CHINA'}
# 19 HEYGATE STREET MARKET HARBOROUGH LEICESTERSHIRE LE16 7JR TAIWAN CHINA
# {'postcode': 'CM3 5YQ', 'region': 'ESSEX', 'street_address': '10 BEATTY RISE SOUTH WOODHAM FERRERS CHELMSFORD', 'country': 'TAIWAN CHINA'}
# 10 BEATTY RISE SOUTH WOODHAM FERRERS CHELMSFORD ESSEX CM3 5YQ TAIWAN CHINA
# {'postcode': 'HU3 3AR', 'region': 'CITY OF KINGSTON UPON HULL', 'street_address': '16 VICTORIA AVENUE HULL', 'country': 'U.K'}
# 16 VICTORIA AVENUE HULL CITY OF KINGSTON UPON HULL HU3 3AR U.K
# {'postcode': 'CA1 1LJ', 'region': 'CUMBRIA', 'street_address': '223 WARWICK ROAD CARLISLE', 'country': 'INDIA'}
# 223 WARWICK ROAD CARLISLE CUMBRIA CA1 1LJ INDIA
# {'postcode': 'PE31 7HZ', 'region': 'NORFOLK', 'street_address': "KELMSCOT, 11 RINGSTEAD ROAD HEACHAM KING'S LYNN", 'country': 'CHINA'}
# KELMSCOT, 11 RINGSTEAD ROAD HEACHAM KING'S LYNN NORFOLK PE31 7HZ CHINA
# {'postcode': 'BB10 3JW', 'region': 'LANCASHIRE', 'street_address': '161 BROWNSIDE ROAD BURNLEY', 'country': 'U.K'}
# 161 BROWNSIDE ROAD BURNLEY LANCASHIRE BB10 3JW U.K
# {'postcode': 'LD3 7FE', 'region': 'POWYS', 'street_address': 'THE BARN 2 CROSS YARD BRECON', 'country': 'P.R.CHINA'}
# THE BARN 2 CROSS YARD BRECON POWYS LD3 7FE P.R.CHINA
# {'postcode': 'SA6 6AX', 'region': 'SWANSEA', 'street_address': '2 TELYN AUR MORRISTON SWANSEA', 'country': 'U.K'}
# 2 TELYN AUR MORRISTON SWANSEA SWANSEA SA6 6AX U.K
# {'postcode': 'SG18 9BU', 'region': 'CENTRAL BEDFORDSHIRE', 'street_address': '116 HITCHIN ROAD UPPER CALDECOTE BIGGLESWADE', 'country': 'U.K'}
# 116 HITCHIN ROAD UPPER CALDECOTE BIGGLESWADE CENTRAL BEDFORDSHIRE SG18 9BU U.K
# {'postcode': 'NP13 3BX', 'region': 'BLAENAU GWENT', 'street_address': '1 CHAPEL ROAD BLAINA ABERTILLERY', 'country': 'IRAN'}
# 1 CHAPEL ROAD BLAINA ABERTILLERY BLAENAU GWENT NP13 3BX IRAN
# {'postcode': 'SS14 3JG', 'region': 'ESSEX', 'street_address': '42 MONTAGUE STREET BASILDON', 'country': 'UK'}
# 42 MONTAGUE STREET BASILDON ESSEX SS14 3JG UK
# {'postcode': 'RH14 9SF', 'region': 'WEST SUSSEX', 'street_address': '38 MORRIS DRIVE BILLINGSHURST', 'country': 'IRAN'}
# 38 MORRIS DRIVE BILLINGSHURST WEST SUSSEX RH14 9SF IRAN
# {'postcode': 'TQ12 1QZ', 'region': 'DEVON', 'street_address': '4 STONELEIGH CLOSE NEWTON ABBOT', 'country': 'INDIA'}
# 4 STONELEIGH CLOSE NEWTON ABBOT DEVON TQ12 1QZ INDIA
# {'postcode': 'EN6 1DG', 'region': 'HERTFORDSHIRE', 'street_address': '18 MANOR ROAD POTTERS BAR', 'country': 'U.K'}
# 18 MANOR ROAD POTTERS BAR HERTFORDSHIRE EN6 1DG U.K
# {'postcode': 'SO51 7NG', 'region': 'HAMPSHIRE', 'street_address': 'HILL HOUSE THE CRESCENT ROMSEY', 'country': 'INDIA'}
# HILL HOUSE THE CRESCENT ROMSEY HAMPSHIRE SO51 7NG INDIA
# {'postcode': 'SN25 4AB', 'region': 'SWINDON', 'street_address': '40 HAYWAIN CLOSE SWINDON', 'country': 'INDIA'}
# 40 HAYWAIN CLOSE SWINDON SWINDON SN25 4AB INDIA
# {'postcode': 'GU11 3EU', 'region': 'HAMPSHIRE', 'street_address': '16 VINE STREET ALDERSHOT', 'country': 'CHINA'}
# 16 VINE STREET ALDERSHOT HAMPSHIRE GU11 3EU CHINA
# {'postcode': 'CF81 8NL', 'region': 'CAERPHILLY', 'street_address': '38 HILLSIDE PARK BARGOED', 'country': 'TAIWAN CHINA'}
# 38 HILLSIDE PARK BARGOED CAERPHILLY CF81 8NL TAIWAN CHINA
# {'postcode': 'TS1 4ET', 'region': 'MIDDLESBROUGH', 'street_address': '2 WENTWORTH STREET MIDDLESBROUGH', 'country': 'P.R.CHINA'}
# 2 WENTWORTH STREET MIDDLESBROUGH MIDDLESBROUGH TS1 4ET P.R.CHINA
# {'postcode': 'NN16 8UH', 'region': 'NORTHAMPTONSHIRE', 'street_address': '79 DERWENT CRESCENT KETTERING', 'country': 'INDIA'}
# 79 DERWENT CRESCENT KETTERING NORTHAMPTONSHIRE NN16 8UH INDIA
# {'postcode': 'IP28 6DN', 'region': 'SUFFOLK', 'street_address': 'THE LONE PINE THE STREET CULFORD BURY ST EDMUNDS', 'country': 'UK'}
# THE LONE PINE THE STREET CULFORD BURY ST EDMUNDS SUFFOLK IP28 6DN UK
# {'postcode': 'LS28 5FF', 'region': 'WEST YORKSHIRE', 'street_address': '12 POPLAR FARM LANE FARSLEY PUDSEY', 'country': 'U.K'}
# 12 POPLAR FARM LANE FARSLEY PUDSEY WEST YORKSHIRE LS28 5FF U.K
# {'postcode': 'TW19 7HY', 'region': 'SURREY', 'street_address': '35 ST MARYS CRESCENT STANWELL STAINES', 'country': 'CHINA'}
# 35 ST MARYS CRESCENT STANWELL STAINES SURREY TW19 7HY CHINA
# {'postcode': 'LA9 6HA', 'region': 'CUMBRIA', 'street_address': '19 BROAD ING CRESCENT KENDAL', 'country': 'TAIWAN CHINA'}
# 19 BROAD ING CRESCENT KENDAL CUMBRIA LA9 6HA TAIWAN CHINA
# {'postcode': 'DA3 8QW', 'region': 'KENT', 'street_address': '36 WESTFIELD NEW ASH GREEN LONGFIELD', 'country': 'P.R.CHINA'}
# 36 WESTFIELD NEW ASH GREEN LONGFIELD KENT DA3 8QW P.R.CHINA
# {'postcode': 'B26 3SL', 'region': 'WEST MIDLANDS', 'street_address': '28 IVYDALE AVENUE SHELDON BIRMINGHAM', 'country': 'U.K'}
# 28 IVYDALE AVENUE SHELDON BIRMINGHAM WEST MIDLANDS B26 3SL U.K
# {'postcode': 'WN1 3PZ', 'region': 'GREATER MANCHESTER', 'street_address': '26 NORTHUMBERLAND STREET WIGAN', 'country': 'U.K'}
# 26 NORTHUMBERLAND STREET WIGAN GREATER MANCHESTER WN1 3PZ U.K
# {'postcode': 'DL6 1AR', 'region': 'NORTH YORKSHIRE', 'street_address': '31 CROSBY GARDENS NORTHALLERTON', 'country': 'IRAN'}
# 31 CROSBY GARDENS NORTHALLERTON NORTH YORKSHIRE DL6 1AR IRAN
# {'postcode': 'ST4 8RT', 'region': 'STOKE-ON-TRENT', 'street_address': '46 JAVA CRESCENT STOKE-ON-TRENT', 'country': 'INDIA'}
# 46 JAVA CRESCENT STOKE-ON-TRENT STOKE-ON-TRENT ST4 8RT INDIA
# {'postcode': 'CF44 6RR', 'region': 'RHONDDA CYNON TAFF', 'street_address': '22 WYNDHAM CRESCENT ABERDARE', 'country': 'TAIWAN CHINA'}
# 22 WYNDHAM CRESCENT ABERDARE RHONDDA CYNON TAFF CF44 6RR TAIWAN CHINA
# {'postcode': 'WF2 0BH', 'region': 'WEST YORKSHIRE', 'street_address': '20 LINDALE MOUNT WAKEFIELD', 'country': 'P.R.CHINA'}
# 20 LINDALE MOUNT WAKEFIELD WEST YORKSHIRE WF2 0BH P.R.CHINA
# {'postcode': 'PO20 0BS', 'region': 'WEST SUSSEX', 'street_address': '70 EAST STREET SELSEY CHICHESTER', 'country': 'U.K'}
# 70 EAST STREET SELSEY CHICHESTER WEST SUSSEX PO20 0BS U.K
# {'postcode': 'B24 9AP', 'region': 'WEST MIDLANDS', 'street_address': '65 TRAFALGAR ROAD ERDINGTON BIRMINGHAM', 'country': 'INDIA'}
# 65 TRAFALGAR ROAD ERDINGTON BIRMINGHAM WEST MIDLANDS B24 9AP INDIA
# {'postcode': 'SL9 8FG', 'region': 'BUCKINGHAMSHIRE', 'street_address': '15 THE PARK GERRARDS CROSS', 'country': 'IRAN'}
# 15 THE PARK GERRARDS CROSS BUCKINGHAMSHIRE SL9 8FG IRAN
# {'postcode': 'LL30 2DL', 'region': 'CONWY', 'street_address': '5 SALISBURY COURT LLANDUDNO', 'country': 'IRAN'}
# 5 SALISBURY COURT LLANDUDNO CONWY LL30 2DL IRAN

# %% [markdown]
# ## Examine those where postcode is not retrieved

# %%
for address in clean_addresses:
    if address['postcode_retrieved'] == False:
        print(address['street_address'], address['region'], address['postcode'], address['country'])
        print(address['dirty'])
        try:
            print(address['parsed']['postcode'])
        except:
            print("no postcode retrieved")
# Out:
# 105 HERON WAY TORQUAY TORBAY TQ2 7SU TAIWAN CHINA
# 105 HERON WAY TORQUAY TORBAY TQ2 7SU TAIWAN CHINA
# tq2
# 1 RHODFA FLINT BODELWYDDAN RHYL DENBIGHSHIRE LL18 5WP U.K
# 1 RHODFA FLINT BODELWYDDAN RHYL DENBIGHSHIRE LL18 5WP U.K
# ll18
# 45 GLYNFACH ROAD PORTH RHONDDA CYNON TAFF CF39 9LF CHINA
# 45 GLYNFACH ROAD PORTH RHONDDA CYNON TAFF CF39 9LF CHINA
# cf39
# ALBORAN APARTMENTS, 1 FLAT 302 SEVEN SEA GARDENS LONDON GREATER LONDON E3 3GU UK
# ALBORAN APARTMENTS, 1 FLAT 302 SEVEN SEA GARDENS LONDON GREATER LONDON E3 3GU UK
# 3gu
# 4 STATION HALT SWINDON SWINDON SN3 4GL P.R.CHINA
# 4 STATION HALT SWINDON SWINDON SN3 4GL P.R.CHINA
# no postcode retrieved
# 100 BROOK ROAD BUCKHURST HILL ESSEX IG9 5FE TAIWAN CHINA
# 100 BROOK ROAD BUCKHURST HILL ESSEX IG9 5FE TAIWAN CHINA
# ig9
# 16 BOSGATE CLOSE BOZEAT WELLINGBOROUGH NORTHAMPTONSHIRE NN29 7JS TAIWAN CHINA
# 16 BOSGATE CLOSE BOZEAT WELLINGBOROUGH NORTHAMPTONSHIRE NN29 7JS TAIWAN CHINA
# nn29
# SKY APARTMENTS FLAT 42 HOMERTON ROAD LONDON GREATER LONDON E9 5FA TAIWAN CHINA
# SKY APARTMENTS FLAT 42 HOMERTON ROAD LONDON GREATER LONDON E9 5FA TAIWAN CHINA
# e9
# 4 PENHALE ROAD PENWITHICK ST AUSTELL CORNWALL PL26 8UP IRAN
# 4 PENHALE ROAD PENWITHICK ST AUSTELL CORNWALL PL26 8UP IRAN
# pl26
# THE VICARAGE SANDHURST ROAD MILFORD HAVEN PEMBROKESHIRE SA73 3JU CHINA
# THE VICARAGE SANDHURST ROAD MILFORD HAVEN PEMBROKESHIRE SA73 3JU CHINA
# no postcode retrieved
# 21 ACORN AVENUE THURNSCOE ROTHERHAM SOUTH YORKSHIRE S63 0AU CHINA
# 21 ACORN AVENUE THURNSCOE ROTHERHAM SOUTH YORKSHIRE S63 0AU CHINA
# no postcode retrieved
# 7 BROCKENHURST ROAD ASCOT WINDSOR AND MAIDENHEAD SL5 9DJ TAIWAN CHINA
# 7 BROCKENHURST ROAD ASCOT WINDSOR AND MAIDENHEAD SL5 9DJ TAIWAN CHINA
# sl5
# 43 TYNEWYDD ROAD BARRY THE VALE OF GLAMORGAN CF62 8AZ U.K
# 43 TYNEWYDD ROAD BARRY THE VALE OF GLAMORGAN CF62 8AZ U.K
# no postcode retrieved
# THE BARN 2 CROSS YARD BRECON POWYS LD3 7FE P.R.CHINA
# THE BARN 2 CROSS YARD BRECON POWYS LD3 7FE P.R.CHINA
# no postcode retrieved
# 1 CHAPEL ROAD BLAINA ABERTILLERY BLAENAU GWENT NP13 3BX IRAN
# 1 CHAPEL ROAD BLAINA ABERTILLERY BLAENAU GWENT NP13 3BX IRAN
# np13
# 22 WYNDHAM CRESCENT ABERDARE RHONDDA CYNON TAFF CF44 6RR TAIWAN CHINA
# 22 WYNDHAM CRESCENT ABERDARE RHONDDA CYNON TAFF CF44 6RR TAIWAN CHINA
# cf44
# 15 THE PARK GERRARDS CROSS BUCKINGHAMSHIRE SL9 8FG IRAN
# 15 THE PARK GERRARDS CROSS BUCKINGHAMSHIRE SL9 8FG IRAN
# sl9
# 5 SALISBURY COURT LLANDUDNO CONWY LL30 2DL IRAN
# 5 SALISBURY COURT LLANDUDNO CONWY LL30 2DL IRAN
# ll30
